# %%
import numpy as np
import pandas as pd
import random
from pathlib import Path
from scipy.stats import zscore
import os
from scipy.stats import ranksums
working_dir = "/Users/nkarisan/PycharmProjects/BTC_Cell_Line_Atlas_Manuscript"
os.chdir(working_dir)

import scripts.io_library as io_library
io_library.input_dir = 'input_data/'
io_library.output_dir = 'Remaining_Analyses/output_files/'

from scripts.io_library import MyLib
from scripts.utils import Utils
from scripts.gene_sets_ssgsea import GSEA

# %%
import matplotlib
seed = 2023
random.seed(seed)
np.random.seed(seed)

matplotlib.use("nbagg")


# %matplotlib inline
# %config InlineBackend.figure_format = "retina"


# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# Pathways enriched in R3 compared to R4, and vice versa, were identified using gene set enrichment analysis, as presented in Supplementary Figure 8.

# %% [markdown]
# # Load dataset

# %%
rna_all_file = 'Main_Data/RNA/rna_cell_lines.csv'
upset_file = 'cell_lines_master_upset_2025-2-24.csv'
maroon_color = '#A00000'
base_color = '#d4d4d4'

# %%
exp_df = MyLib.load_csv(rna_all_file, index_col=0)
exp_df = exp_df.T # samples are the rows

raw_upset_df = MyLib.load_csv(upset_file)
raw_upset_df.set_index('Cell_line', inplace=True, drop=True)
upset_df = raw_upset_df[raw_upset_df['RNA']==1]

upset_df = upset_df[["Subtype"]]
upset_df = upset_df.loc[exp_df.index, :]
# Out:
# input_data/Main_Data/RNA/rna_cell_lines.csv  is loaded, shape:  (17649, 79)
#
# input_data/cell_lines_master_upset_2025-2-24.csv  is loaded, shape:  (87, 12)

# %%
upset_df
# Out:
#           Subtype
# CCLP1         ICC
# CCSW1         ICC
# AOVC1          AC
# ECC3          ECC
# EGI1          ECC
# ...           ...
# TFK1          ECC
# TGBC1TKB      GBC
# TGBC52TKB      AC
# TKKK          ICC
# YSCCC         ICC
#
# [79 rows x 1 columns]

# %% [markdown]
# # Gene Sets ssGSEA: R3 vs R4

# %%
RNA_upset_file = 'Figure5/output_fig5/RNA_Gene_reordered_upset_df.csv'
RNA_upset_df = pd.read_csv(RNA_upset_file, index_col=0)
r3_ids_l = RNA_upset_df[RNA_upset_df['RNA_Cluster']=='R3'].index.tolist()
r4_ids_l = RNA_upset_df[RNA_upset_df['RNA_Cluster']=='R4'].index.tolist()
print(len(r3_ids_l), len(r4_ids_l))
# Out:
# 22 23

# %%
gene_sets_ssgsea_file = 'gene_sets_ssgsea_zscore.csv'
if Path(os.path.join(io_library.output_dir, gene_sets_ssgsea_file)).is_file():
    gene_sets_ssgsea_zscore_df = pd.read_csv(os.path.join(io_library.output_dir, gene_sets_ssgsea_file), index_col=0)
    print('gene_sets_ssgsea_zscore.csv is loaded, shape:', gene_sets_ssgsea_zscore_df.shape)
else:
    ## First run gene_sets_ssgsea.py to create 'gene_sets_ssgsea_zscore.csv' (Takes few hours)
    msigdb_dir = 'input_data/Additional_Data/Selected_Lists/msigdb_v2023.2.Hs_GMTs/'
    gene_sets_ssgsea_zscore_df = GSEA.run_gene_sets_ssgsea_analysis(rna_all_file, upset_file, msigdb_dir)
print(gene_sets_ssgsea_zscore_df.shape)
gene_sets_ssgsea_zscore_df.T.head()
# Out:
# Program started at 2025/04/22 23:47:01
#
# input_data/cell_lines_master_upset_2025-2-24.csv  is loaded, shape:  (87, 12)
#
# input_data/Main_Data/RNA/rna_cell_lines.csv  is loaded, shape:  (17649, 79)
#
# input_data/Additional_Data/Selected_Lists/msigdb_v2023.2.Hs_GMTs/c2.all.v2023.2.Hs.symbols.gmt
# 7233
# input_data/Additional_Data/Selected_Lists/msigdb_v2023.2.Hs_GMTs/c5.all.v2023.2.Hs.symbols.gmt
# 16008
# input_data/Additional_Data/Selected_Lists/msigdb_v2023.2.Hs_GMTs/c4.all.v2023.2.Hs.symbols.gmt
# 1007
# input_data/Additional_Data/Selected_Lists/msigdb_v2023.2.Hs_GMTs/c8.all.v2023.2.Hs.symbols.gmt
# 830
# input_data/Additional_Data/Selected_Lists/msigdb_v2023.2.Hs_GMTs/c6.all.v2023.2.Hs.symbols.gmt
# 189
#
# Total gene sets: 25245
# Number of cpus: 10
# 1264
# [1] "Calculating ranks..."
# 5688
# [1] "Calculating ranks..."
# [1] "Calculating absolute values from ranks..."
# [1] "Calculating absolute values from ranks..."
# [1] "Normalizing..."
# [1] "Normalizing..."
# 4424
# [1] "Calculating ranks..."
# [1] "Calculating absolute values from ranks..."
# [1] "Normalizing..."
# 4425
# [1] "Calculating ranks..."
# 1896
# [1] "Calculating ranks..."
# [1] "Calculating absolute values from ranks..."
# [1] "Calculating absolute values from ranks..."
# 632
# [1] "Calculating ranks..."
# [1] "Calculating absolute values from ranks..."
# 3160
# [1] "Calculating ranks..."
# [1] "Normalizing..."
# [1] "Calculating absolute values from ranks..."
# [1] "Normalizing..."
# [1] "Normalizing..."
# 0
# [1] "Calculating ranks..."
# [1] "Calculating absolute values from ranks..."
# 2528
# [1] "Calculating ranks..."
# [1] "Normalizing..."
# [1] "Calculating absolute values from ranks..."
# 5056
# [1] "Calculating ranks..."
# [1] "Calculating absolute values from ranks..."
# [1] "Normalizing..."
# [1] "Normalizing..."
# 5689
# [1] "Calculating ranks..."
# [1] "Calculating absolute values from ranks..."
# [1] "Normalizing..."
# 3792
# [1] "Calculating ranks..."
# [1] "Calculating absolute values from ranks..."
# [1] "Normalizing..."
# [1] "Normalizing..."
# 1265
# [1] "Calculating ranks..."
# [1] "Calculating absolute values from ranks..."
# [1] "Normalizing..."
# 633
# [1] "Calculating ranks..."
# 4426
# [1] "Calculating ranks..."
# [1] "Calculating absolute values from ranks..."
# 3161
# [1] "Calculating ranks..."
# [1] "Normalizing..."
# 1897
# [1] "Calculating ranks..."
# [1] "Calculating absolute values from ranks..."
# [1] "Calculating absolute values from ranks..."
# [1] "Normalizing..."
# [1] "Calculating absolute values from ranks..."
# [1] "Normalizing..."
# [1] "Normalizing..."
# 5057
# [1] "Calculating ranks..."
# 1
# [1] "Calculating ranks..."
# [1] "Calculating absolute values from ranks..."
# [1] "Normalizing..."
# 1266
# [1] "Calculating ranks..."
# [1] "Calculating absolute values from ranks..."
# [1] "Calculating absolute values from ranks..."
# [1] "Normalizing..."
# [1] "Normalizing..."
# 4427
# [1] "Calculating ranks..."
# [1] "Calculating absolute values from ranks..."
# [1] "Normalizing..."
# 1267
# [1] "Calculating ranks..."
# [1] "Calculating absolute values from ranks..."
# [1] "Normalizing..."
# 1268
# [1] "Calculating ranks..."
# [1] "Calculating absolute values from ranks..."
# 4428
# [1] "Calculating ranks..."
# [1] "Normalizing..."
# [1] "Calculating absolute values from ranks..."
# [1] "Normalizing..."
# 1269
# [1] "Calculating ranks..."
# [1] "Calculating absolute values from ranks..."
# 5690
# [1] "Calculating ranks..."
# [1] "Normalizing..."
# [1] "Calculating absolute values from ranks..."
# 4429
# [1] "Calculating ranks..."
# [1] "Calculating absolute values from ranks..."
# [1] "Normalizing..."
# [1] "Normalizing..."
# 2529
# [1] "Calculating ranks..."
# [1] "Calculating absolute values from ranks..."
# [1] "Normalizing..."
# 1270
# [1] "Calculating ranks..."
# [1] "Calculating absolute values from ranks..."
# 4430
# [1] "Calculating ranks..."
# [1] "Calculating absolute values from ranks..."
# 5691
# [1] "Calculating ranks..."
# [1] "Calculating absolute values from ranks..."
# [1] "Normalizing..."
# 634
# [1] "Calculating ranks..."
# [1] "Calculating absolute values from ranks..."
# 5692
# [1] "Calculating ranks..."
# [1] "Calculating absolute values from ranks..."
# [1] "Normalizing..."
# [1] "Normalizing..."
# 5693
# [1] "Calculating ranks..."
# [1] "Calculating absolute values from ranks..."
# [1] "Normalizing..."
# 5694
# [1] "Calculating ranks..."
# [1] "Calculating absolute values from ranks..."
# 635
# [1] "Calculating ranks..."
# [1] "Calculating absolute values from ranks..."
# [1] "Normalizing..."
# 2
# [1] "Calculating ranks..."
# [1] "Calculating absolute values from ranks..."
# 3162
# [1] "Calculating ranks..."
# [1] "Normalizing..."
# [1] "Calculating absolute values from ranks..."
# 1898
# [1] "Calculating ranks..."
# [1] "Calculating absolute values from ranks..."
# [1] "Normalizing..."
# 636
# [1] "Calculating ranks..."
# [1] "Normalizing..."
# [1] "Calculating absolute values from ranks..."
# [1] "Normalizing..."
# 5058
# [1] "Calculating ranks..."
# [1] "Calculating absolute values from ranks..."
# [1] "Normalizing..."
# 3793
# [1] "Calculating ranks..."
# 637
# [1] "Calculating ranks..."
# [1] "Calculating absolute values from ranks..."
# [1] "Normalizing..."
# [1] "Calculating absolute values from ranks..."
# 3
# [1] "Calculating ranks..."
# [1] "Calculating absolute values from ranks..."
# [1] "Normalizing..."
# 3163
# [1] "Calculating ranks..."
# [1] "Calculating absolute values from ranks..."
# [1] "Normalizing..."
# 638
# [1] "Calculating ranks..."
# [1] "Calculating absolute values from ranks..."
# 1899
# [1] "Calculating ranks..."
# [1] "Calculating absolute values from ranks..."
# [1] "Normalizing..."
# [1] "Normalizing..."
# 4
# [1] "Calculating ranks..."
# [1] "Calculating absolute values from ranks..."
# 5059
# [1] "Calculating ranks..."
# [1] "Calculating absolute values from ranks..."
# [1] "Normalizing..."
# [1] "Normalizing..."
# 3164
# [1] "Calculating ranks..."
# 1900
# [1] "Calculating ranks..."
# [1] "Calculating absolute values from ranks..."
# [1] "Calculating absolute values from ranks..."
# [1] "Normalizing..."
# [1] "Normalizing..."
# 5
# [1] "Calculating ranks..."
# [1] "Calculating absolute values from ranks..."
# [1] "Normalizing..."
# 5060
# [1] "Calculating ranks..."
# [1] "Calculating absolute values from ranks..."
# [1] "Normalizing..."
# [1] "Normalizing..."
# 3165
# [1] "Calculating ranks..."
# 1901
# [1] "Calculating ranks..."
# [1] "Calculating absolute values from ranks..."
# [1] "Calculating absolute values from ranks..."
# 6
# [1] "Calculating ranks..."
# [1] "Normalizing..."
# [1] "Calculating absolute values from ranks..."
# [1] "Normalizing..."
# 1271
# [1] "Calculating ranks..."
# 5061
# [1] "Calculating ranks..."
# [1] "Calculating absolute values from ranks..."
# [1] "Calculating absolute values from ranks..."
# [1] "Normalizing..."
# [1] "Normalizing..."
# 3166
# [1] "Calculating ranks..."
# 1902
# [1] "Calculating ranks..."
# [1] "Calculating absolute values from ranks..."
# [1] "Calculating absolute values from ranks..."
# 2530
# [1] "Calculating ranks..."
# [1] "Calculating absolute values from ranks..."
# 5062
# [1] "Calculating ranks..."
# [1] "Calculating absolute values from ranks..."
# [1] "Normalizing..."
# 2531
# [1] "Calculating ranks..."
# [1] "Calculating absolute values from ranks..."
# [1] "Normalizing..."
# [1] "Normalizing..."
# [1] "Normalizing..."
# 2532
# [1] "Calculating ranks..."
# [1] "Calculating absolute values from ranks..."
# [1] "Normalizing..."
# 4431
# [1] "Calculating ranks..."
# [1] "Calculating absolute values from ranks..."
# 5695
# [1] "Calculating ranks..."
# 2533
# [1] "Calculating ranks..."
# [1] "Calculating absolute values from ranks..."
# [1] "Normalizing..."
# [1] "Normalizing..."
# [1] "Calculating absolute values from ranks..."
# [1] "Normalizing..."
# [1] "Normalizing..."
# 2534
# [1] "Calculating ranks..."
# 3794
# [1] "Calculating ranks..."
# [1] "Calculating absolute values from ranks..."
# [1] "Calculating absolute values from ranks..."
# [1] "Normalizing..."
# 639
# [1] "Calculating ranks..."
# 1272
# [1] "Calculating ranks..."
# [1] "Calculating absolute values from ranks..."
# [1] "Calculating absolute values from ranks..."
# [1] "Normalizing..."
# [1] "Normalizing..."
# 3795
# [1] "Calculating ranks..."
# [1] "Calculating absolute values from ranks..."
# [1] "Normalizing..."
# 3796
# [1] "Calculating ranks..."
# 1273
# [1] "Calculating ranks..."
# [1] "Calculating absolute values from ranks..."
# [1] "Calculating absolute values from ranks..."
# [1] "Normalizing..."
# [1] "Normalizing..."
# [1] "Normalizing..."
# 3797
# [1] "Calculating ranks..."
# 1274
# [1] "Calculating ranks..."
# [1] "Calculating absolute values from ranks..."
# [1] "Calculating absolute values from ranks..."
# [1] "Normalizing..."
# [1] "Normalizing..."
# [1] "Normalizing..."
# [1] "Normalizing..."
# 1275
# [1] "Calculating ranks..."
# [1] "Calculating absolute values from ranks..."
# [1] "Normalizing..."
# 3798
# [1] "Calculating ranks..."
# [1] "Calculating absolute values from ranks..."
# 7
# [1] "Calculating ranks..."
# [1] "Normalizing..."
# 3167
# [1] "Calculating ranks..."
# 5063
# [1] "Calculating ranks..."
# [1] "Calculating absolute values from ranks..."
# [1] "Calculating absolute values from ranks..."
# 1276
# [1] "Calculating ranks..."
# [1] "Calculating absolute values from ranks..."
# [1] "Calculating absolute values from ranks..."
# [1] "Normalizing..."
# 1903
# [1] "Calculating ranks..."
# [1] "Normalizing..."
# [1] "Normalizing..."
# [1] "Calculating absolute values from ranks..."
# 5696
# [1] "Calculating ranks..."
# [1] "Calculating absolute values from ranks..."
# [1] "Normalizing..."
# [1] "Normalizing..."
# 4432
# [1] "Calculating ranks..."
# [1] "Calculating absolute values from ranks..."
# 5697
# [1] "Calculating ranks..."
# [1] "Normalizing..."
# [1] "Calculating absolute values from ranks..."
# [1] "Normalizing..."
# [1] "Normalizing..."
# 640
# [1] "Calculating ranks..."
# [1] "Calculating absolute values from ranks..."
# [1] "Normalizing..."
# 5698
# [1] "Calculating ranks..."
# [1] "Calculating absolute values from ranks..."
# [1] "Normalizing..."
# 4433
# [1] "Calculating ranks..."
# 2535
# [1] "Calculating ranks..."
# [1] "Calculating absolute values from ranks..."
# [1] "Normalizing..."
# [1] "Normalizing..."
# 5699
# [1] "Calculating ranks..."
# [1] "Calculating absolute values from ranks..."
# [1] "Calculating absolute values from ranks..."
# [1] "Normalizing..."
# [1] "Normalizing..."
# 1277
# [1] "Calculating ranks..."
# 4434
# [1] "Calculating ranks..."
# [1] "Calculating absolute values from ranks..."
# [1] "Normalizing..."
# 5700
# [1] "Calculating ranks..."
# [1] "Calculating absolute values from ranks..."
# [1] "Calculating absolute values from ranks..."
# 641
# [1] "Calculating ranks..."
# [1] "Calculating absolute values from ranks..."
# [1] "Normalizing..."
# 4435
# [1] "Calculating ranks..."
# [1] "Calculating absolute values from ranks..."
# [1] "Normalizing..."
# 1278
# [1] "Calculating ranks..."
# [1] "Calculating absolute values from ranks..."
# [1] "Normalizing..."
# 642
# [1] "Calculating ranks..."
# [1] "Calculating absolute values from ranks..."
# [1] "Normalizing..."
# 643
# [1] "Calculating ranks..."
# [1] "Calculating absolute values from ranks..."
# [1] "Normalizing..."
# 8
# [1] "Calculating ranks..."
# [1] "Calculating absolute values from ranks..."
# [1] "Normalizing..."
# 3168
# [1] "Calculating ranks..."
# [1] "Calculating absolute values from ranks..."
# 644
# [1] "Calculating ranks..."
# [1] "Normalizing..."
# [1] "Calculating absolute values from ranks..."
# 1904
# [1] "Calculating ranks..."
# [1] "Calculating absolute values from ranks..."
# [1] "Normalizing..."
# 9
# [1] "Calculating ranks..."
# [1] "Calculating absolute values from ranks..."
# 5064
# [1] "Calculating ranks..."
# [1] "Calculating absolute values from ranks..."
# [1] "Normalizing..."
# [1] "Normalizing..."
# 3169
# [1] "Calculating ranks..."
# [1] "Calculating absolute values from ranks..."
# 2536
# [1] "Calculating ranks..."
# [1] "Calculating absolute values from ranks..."
# 10
# [1] "Calculating ranks..."
# [1] "Calculating absolute values from ranks..."
# [1] "Normalizing..."
# [1] "Normalizing..."
# [1] "Normalizing..."
# [1] "Normalizing..."
# 1905
# [1] "Calculating ranks..."
# [1] "Calculating absolute values from ranks..."
# [1] "Normalizing..."
# 11
# [1] "Calculating ranks..."
# [1] "Calculating absolute values from ranks..."
# 5065
# [1] "Calculating ranks..."
# [1] "Normalizing..."
# [1] "Calculating absolute values from ranks..."
# [1] "Normalizing..."
# [1] "Normalizing..."
# 3170
# [1] "Calculating ranks..."
# 3799
# [1] "Calculating ranks..."
# [1] "Calculating absolute values from ranks..."
# [1] "Normalizing..."
# 2537
# [1] "Calculating ranks..."
# [1] "Normalizing..."
# [1] "Calculating absolute values from ranks..."
# 1906
# [1] "Calculating ranks..."
# [1] "Calculating absolute values from ranks..."
# [1] "Normalizing..."
# [1] "Calculating absolute values from ranks..."
# [1] "Normalizing..."
# [1] "Normalizing..."
# 12
# [1] "Calculating ranks..."
# [1] "Calculating absolute values from ranks..."
# 5066
# [1] "Calculating ranks..."
# [1] "Calculating absolute values from ranks..."
# [1] "Normalizing..."
# 3171
# [1] "Calculating ranks..."
# 4436
# [1] "Calculating ranks..."
# [1] "Calculating absolute values from ranks..."
# [1] "Calculating absolute values from ranks..."
# [1] "Normalizing..."
# 2538
# [1] "Calculating ranks..."
# [1] "Calculating absolute values from ranks..."
# [1] "Normalizing..."
# 5701
# [1] "Calculating ranks..."
# 1907
# [1] "Calculating ranks..."
# [1] "Calculating absolute values from ranks..."
# 2539
# [1] "Calculating ranks..."
# [1] "Calculating absolute values from ranks..."
# [1] "Normalizing..."
# 5067
# [1] "Calculating ranks..."
# [1] "Normalizing..."
# [1] "Calculating absolute values from ranks..."
# [1] "Normalizing..."
# [1] "Calculating absolute values from ranks..."
# 2540
# [1] "Calculating ranks..."
# [1] "Normalizing..."
# 1908
# [1] "Calculating ranks..."
# [1] "Calculating absolute values from ranks..."
# [1] "Calculating absolute values from ranks..."
# 1279
# [1] "Calculating ranks..."
# [1] "Calculating absolute values from ranks..."
# 4437
# [1] "Calculating ranks..."
# [1] "Calculating absolute values from ranks..."
# 5702
# [1] "Calculating ranks..."
# [1] "Calculating absolute values from ranks..."
# [1] "Normalizing..."
# [1] "Normalizing..."
# [1] "Normalizing..."
# 1280
# [1] "Calculating ranks..."
# [1] "Calculating absolute values from ranks..."
# [1] "Normalizing..."
# [1] "Normalizing..."
# 1281
# [1] "Calculating ranks..."
# [1] "Calculating absolute values from ranks..."
# [1] "Normalizing..."
# [1] "Normalizing..."
# 645
# [1] "Calculating ranks..."
# 1282
# [1] "Calculating ranks..."
# [1] "Calculating absolute values from ranks..."
# [1] "Calculating absolute values from ranks..."
# [1] "Normalizing..."
# 2541
# [1] "Calculating ranks..."
# [1] "Calculating absolute values from ranks..."
# [1] "Normalizing..."
# 646
# [1] "Calculating ranks..."
# [1] "Calculating absolute values from ranks..."
# [1] "Normalizing..."
# 2542
# [1] "Calculating ranks..."
# [1] "Calculating absolute values from ranks..."
# [1] "Normalizing..."
# [1] "Normalizing..."

# %%
gene_sets_ssgsea_zscore_df.shape
# Out:
# (56, 25245)

# %%
r3_gene_sets_ssgsea_zscore_df = gene_sets_ssgsea_zscore_df.loc[r3_ids_l]
r4_gene_sets_ssgsea_zscore_df = gene_sets_ssgsea_zscore_df.loc[r4_ids_l]

# %%
r4_gene_sets_ssgsea_zscore_df
# Out:
#            ABBUD_LIF_SIGNALING_1_DN  ABBUD_LIF_SIGNALING_1_UP  \
# Cell_line
# ICC9                      -1.055671                 -0.959971
# HUCCT1                    -1.116497                 -0.801913
# ICC8                       0.604952                  0.174533
# ICC12                     -1.043329                 -0.250657
# EGI1                      -0.061561                  0.279287
# AOVC1                     -0.531920                 -0.709072
# TGBC1TKB                  -1.104900                  0.883849
# YSCCC                     -0.583315                  0.297255
# ICC2                      -0.434974                  0.535755
# ECC3                      -0.976794                  1.085445
# HKGZCC                     0.708412                  0.996312
# KKU213                     0.127265                  0.067633
# SNU308                     1.036159                 -1.502369
# CCSW1                     -0.078455                 -1.642104
# KMCH1                     -1.490574                 -0.793571
# TFK1                      -0.087150                  0.003805
# SNU478                     0.646917                 -0.116202
# SNU869                     0.182941                  0.590411
# SNU1196                    0.296823                 -0.692492
# TKKK                       1.464964                 -0.855837
# SNU245                     1.452569                 -1.141679
# OZ                        -0.143255                  0.270860
# GB2                       -0.062916                  1.308844
#
#            ABBUD_LIF_SIGNALING_2_DN  ABBUD_LIF_SIGNALING_2_UP  \
# Cell_line
# ICC9                      -0.959715                 -1.528777
# HUCCT1                     1.227025                 -1.513305
# ICC8                       0.311275                 -0.385488
# ICC12                      0.570472                 -0.917022
# EGI1                      -0.126429                  0.197850
# AOVC1                     -1.478560                  0.216136
# TGBC1TKB                   0.450230                 -0.499096
# YSCCC                      1.012507                  0.472771
# ICC2                       0.255612                 -0.703450
# ECC3                       0.212048                 -0.669452
# HKGZCC                    -0.260608                 -0.911111
# KKU213                    -0.051146                  0.267853
# SNU308                     0.199126                  0.157036
# CCSW1                      1.811376                  0.630279
# KMCH1                     -2.152962                 -0.476293
# TFK1                      -0.390282                  0.589731
# SNU478                     1.081069                  0.516246
# SNU869                    -1.423368                 -0.943587
# SNU1196                   -2.497545                 -1.217358
# TKKK                      -0.013599                 -0.252164
# SNU245                    -0.202594                 -1.066427
# OZ                        -0.732782                 -0.350252
# GB2                       -0.023437                  1.150290
#
#            ABDELMOHSEN_ELAVL4_TARGETS  ABDULRAHMAN_KIDNEY_CANCER_VHL_DN  \
# Cell_line
# ICC9                        -1.766995                         -1.162723
# HUCCT1                      -0.380342                         -0.445225
# ICC8                        -1.565966                         -0.809576
# ICC12                       -0.319883                         -2.211107
# EGI1                        -2.480126                         -1.305544
# AOVC1                       -0.964475                         -0.458292
# TGBC1TKB                    -0.007753                         -0.538559
# YSCCC                       -0.143076                          0.545085
# ICC2                        -1.728758                         -0.460847
# ECC3                        -2.379331                         -0.862014
# HKGZCC                      -1.598701                         -1.970051
# KKU213                       0.331150                         -0.508414
# SNU308                      -0.079985                          0.446353
# CCSW1                       -1.021880                          0.734110
# KMCH1                        0.255641                          0.003428
# TFK1                         0.569491                          0.559138
# SNU478                       0.103941                         -0.247599
# SNU869                       0.066338                         -0.193613
# SNU1196                      0.339056                         -2.267803
# TKKK                        -0.120953                         -0.717693
# SNU245                      -0.917902                         -2.113425
# OZ                          -0.465718                         -1.269952
# GB2                          0.217303                          0.829289
#
#            ABE_INNER_EAR  ABE_VEGFA_TARGETS  ABE_VEGFA_TARGETS_2HR  \
# Cell_line
# ICC9           -0.061337           1.494974               1.072545
# HUCCT1         -0.765887           1.607359              -0.351352
# ICC8           -0.571195           1.630972               1.439877
# ICC12           0.261571           2.063891               1.767242
# EGI1            1.293772          -1.358384               0.214240
# AOVC1           0.737621           0.693266               0.791520
# TGBC1TKB       -0.081908           1.259358               1.507725
# YSCCC          -0.926960          -0.123335               0.231471
# ICC2           -0.598017          -1.173071              -0.989619
# ECC3            0.732841           1.428901               0.995957
# HKGZCC          0.861170           1.632288               1.217049
# KKU213         -0.197502           1.373295               1.245406
# SNU308         -2.808542          -1.070830               0.767516
# CCSW1           1.344117           0.047436              -0.390748
# KMCH1           0.032042          -1.068923              -0.408304
# TFK1           -1.361055           0.111656              -0.879042
# SNU478         -1.737058           0.548947               0.382765
# SNU869         -1.913256           0.225095               0.226064
# SNU1196         0.164236           0.168598               0.296420
# TKKK           -1.330643          -0.308977               1.387380
# SNU245         -0.233772          -1.318964              -1.214472
# OZ              1.358069          -0.870280               0.520190
# GB2             1.354221           0.227890              -1.388500
#
#            ABE_VEGFA_TARGETS_30MIN  ...  TBK1.DN.48HRS_DN  TBK1.DN.48HRS_UP  \
# Cell_line                           ...
# ICC9                      0.962177  ...         -1.863400         -2.565998
# HUCCT1                    0.950891  ...          0.629244         -1.427698
# ICC8                     -0.316799  ...         -0.401127         -1.409628
# ICC12                     1.200361  ...          0.361632         -1.976693
# EGI1                     -0.821536  ...         -0.133383         -2.094759
# AOVC1                     0.640656  ...         -0.071410         -0.031816
# TGBC1TKB                  0.390145  ...          0.849593         -1.063183
# YSCCC                    -1.407089  ...         -0.667453          0.506408
# ICC2                      0.716452  ...          1.166110         -0.980855
# ECC3                      1.429371  ...          0.382497          0.005100
# HKGZCC                   -0.027027  ...         -0.712275         -0.946292
# KKU213                    0.459232  ...          0.481715          0.904134
# SNU308                    0.308277  ...         -1.186273          1.457904
# CCSW1                    -0.415643  ...         -1.203764          0.293329
# KMCH1                     0.066447  ...          0.519209          1.062959
# TFK1                     -0.842493  ...          1.192661          0.860878
# SNU478                    0.566013  ...          0.449392          0.594560
# SNU869                    1.436949  ...         -1.521164          0.022947
# SNU1196                   0.501909  ...         -1.615702         -0.307109
# TKKK                      0.782150  ...          2.282957         -0.166993
# SNU245                    0.311592  ...         -2.430344          0.310489
# OZ                        1.144509  ...          0.253365         -2.221819
# GB2                      -1.355063  ...          0.005521          1.097403
#
#            TGFB_UP.V1_DN  TGFB_UP.V1_UP  VEGF_A_UP.V1_DN  VEGF_A_UP.V1_UP  \
# Cell_line
# ICC9           -2.315821      -0.759019        -0.703572        -1.452274
# HUCCT1         -0.087250      -1.022558         1.229868        -1.260291
# ICC8            0.754456      -0.147045        -0.198405        -0.308803
# ICC12          -1.401867       0.690269        -0.085698         0.234329
# EGI1            0.627492      -0.853384        -2.221267         0.509756
# AOVC1          -0.151301      -0.142134        -0.523277        -0.503552
# TGBC1TKB       -0.168662      -0.217218         0.011223        -0.055325
# YSCCC           0.060064      -0.836895        -0.912110        -0.626488
# ICC2            0.202605      -0.171593        -1.026185         0.278242
# ECC3            1.107317      -0.245272         0.041723        -1.073214
# HKGZCC         -0.263024      -0.526156        -0.976295        -0.001655
# KKU213          1.510488      -0.867722         0.911062        -1.054198
# SNU308          1.067490      -0.256133         0.740127        -0.941023
# CCSW1           0.105309      -0.291555         0.682444        -1.109550
# KMCH1          -0.832337      -1.476891        -0.863623        -0.145046
# TFK1            0.050774       0.081301         1.591191        -1.486639
# SNU478          0.836489       1.368683         1.285860        -0.872800
# SNU869         -0.337586       0.111478        -0.532099         0.555864
# SNU1196        -1.097151       0.494888         0.623862        -0.298037
# TKKK            0.020400      -0.749248         1.329746        -1.136445
# SNU245         -0.795479      -1.237810         0.146376        -0.535329
# OZ              0.142624      -0.850893        -1.991628         0.631569
# GB2             1.370222      -0.257215        -0.376416         0.155932
#
#            WNT_UP.V1_DN  WNT_UP.V1_UP   YAP1_DN   YAP1_UP
# Cell_line
# ICC9          -0.310199     -0.309860  0.108854 -1.452580
# HUCCT1        -0.833773     -0.556581 -1.136982  0.178972
# ICC8          -0.059100      1.060980  0.750303  0.956239
# ICC12          0.773834      0.285866  0.871878  0.093963
# EGI1           0.962311      0.969339 -0.458061 -1.329489
# AOVC1         -0.146975     -1.611922 -0.801813 -0.762515
# TGBC1TKB       0.315758     -0.466302  0.403474  1.369719
# YSCCC         -1.066459     -0.485043  0.623464  1.590242
# ICC2           1.100571      0.814600 -1.294231 -0.310339
# ECC3          -0.301379     -0.032125  0.883965 -1.251157
# HKGZCC         0.954961      0.469114 -0.017763 -1.732697
# KKU213        -0.547275     -1.645045  0.195069 -0.825379
# SNU308        -0.392872      0.824284  0.583037 -0.528165
# CCSW1         -0.462884     -0.179785  0.816344  0.598062
# KMCH1         -0.281686      0.275900 -0.113689 -0.054653
# TFK1          -0.441180     -0.932843 -0.070796  0.265419
# SNU478        -0.659608      1.833050  0.780464 -0.066135
# SNU869         1.109727      0.123650  0.574222 -1.497640
# SNU1196       -0.750930     -0.625435 -0.509916 -1.683270
# TKKK          -0.770621     -0.079826 -1.045459 -0.421621
# SNU245        -0.285411     -0.381962  0.772436 -1.998668
# OZ             0.322395      0.906491  0.575560 -1.352935
# GB2            1.154182     -0.566918  0.387726 -0.028036
#
# [23 rows x 25245 columns]

# %%
Utils.statistical_test_and_volcano_plot(r3_gene_sets_ssgsea_zscore_df, r4_gene_sets_ssgsea_zscore_df, test='ranksum', plot_volcano=False, save_sig=True, title='R3_vs_R4_gene_sets_ssgsea_zscore')
# Out:
# File  Remaining_Analyses/output_files/R3_vs_R4_gene_sets_ssgsea_zscore_down.csv saved, shape: (1230, 7)
#
# File  Remaining_Analyses/output_files/R3_vs_R4_gene_sets_ssgsea_zscore_up.csv saved, shape: (8647, 7)
#                                                  feature      stat  \
# 0      HP_GLUCOCORTOCOID_INSENSITIVE_PRIMARY_HYPERALD... -4.949860
# 1      HP_UNDETECTABLE_LIGHT_AND_DARK_ADAPTED_ELECTRO... -4.859037
# 2      GOBP_COMMON_MYELOID_PROGENITOR_CELL_PROLIFERATION -4.722802
# 3                           HAY_BONE_MARROW_CD34_POS_ERP -4.700097
# 4                                               HP_SHOCK -4.654685
# ...                                                  ...       ...
# 25240          WP_ANGIOTENSIN_II_RECEPTOR_TYPE_1_PATHWAY  5.472093
# 25241          REACTOME_CHONDROITIN_SULFATE_BIOSYNTHESIS  5.472093
# 25242  REACTOME_RESPONSE_TO_ELEVATED_PLATELET_CYTOSOL...  5.562916
# 25243                                     HP_HEMATEMESIS  5.562916
# 25244                 ANDERSEN_CHOLANGIOCARCINOMA_CLASS1  5.699151
#
#             p-value  effect_size   q-value  in_group_mean  out_group_mean
# 0      7.426677e-07    -0.737882  0.000170      -0.638144        0.814816
# 1      1.179580e-06    -0.724342  0.000187      -0.868642        0.592517
# 2      2.326167e-06    -0.704034  0.000241      -0.810625        0.660669
# 3      2.600383e-06    -0.700649  0.000248      -0.603155        0.702208
# 4      3.244762e-06    -0.693879  0.000269      -0.695386        0.716997
# ...             ...          ...       ...            ...             ...
# 25240  4.447506e-08     0.815732  0.000138       0.820023       -0.837814
# 25241  4.447506e-08     0.815732  0.000138       0.823804       -0.808637
# 25242  2.653030e-08     0.829271  0.000138       0.887520       -0.797843
# 25243  2.653030e-08     0.829271  0.000138       1.025298       -0.782906
# 25244  1.204055e-08     0.849579  0.000138       1.061802       -0.467732
#
# [25245 rows x 7 columns]
