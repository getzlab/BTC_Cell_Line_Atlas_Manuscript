# %%
import numpy as np
import pandas as pd
import random
from scipy.stats import zscore
import os
working_dir = "/Users/nkarisan/PycharmProjects/BTC_Cell_Line_Atlas_Manuscript"
os.chdir(working_dir)

import BTC_Cell_Line_Atlas_Manuscript.scripts.io_library as io_library
io_library.input_dir = 'input_data/'
io_library.output_dir = 'Remaining_Analyses/output_figs_patients/'

from BTC_Cell_Line_Atlas_Manuscript.scripts.io_library import MyLib
from BTC_Cell_Line_Atlas_Manuscript.scripts.visualization import MyVisualization
from BTC_Cell_Line_Atlas_Manuscript.scripts.utils import Utils
from BTC_Cell_Line_Atlas_Manuscript.scripts.invoking_R_functions import MyRFunctions

# %%
import matplotlib
seed = 2023
random.seed(seed)
np.random.seed(seed)

matplotlib.use("nbagg")


# %matplotlib inline
# %config InlineBackend.figure_format = "retina"


# %load_ext autoreload
# %autoreload 2

# %%
R3_features_file = 'Figure5/output_fig5/R3_features_Up.csv'
R3_features = pd.read_csv(R3_features_file)['feature'].tolist()
print(len(R3_features))
# Out:
# 50

# %%
R4_features_file = 'Figure5/output_fig5/R4_features_Up.csv'
R4_features = pd.read_csv(R4_features_file)['feature'].tolist()
print(len(R4_features))
# Out:
# 50

# %%
# MT_color = '#2C4E78'
# WT_color = '#CED5E0'
control_color = '#c9c7c7'
R3_color = MyVisualization.feat_colors_dic['RNA_Cluster']['R3']
R4_color = MyVisualization.feat_colors_dic['RNA_Cluster']['R4']
color_dic = {'R3': R3_color, 'R3 & R4':'#A00000', 'R4': R4_color, 'WT': '#d4d4d4'}#'#ffa600'

# %% [markdown]
# # ICGC

# %% [markdown]
# RPKM normalized transcripts

# %%
ICGC_file =  'Patients_Data/ICGC/ICGC_dataset.xlsx'
data_df = MyLib.load_xls(ICGC_file, sheet_no=0)
ICGC_info_df = data_df.loc[:10, :].T
ICGC_info_df.columns = ICGC_info_df.iloc[0] 
ICGC_info_df = ICGC_info_df[1:]
ICGC_info_df.columns
# Out:
# Index([                      'Donor_sex',                'Age_at_diagnosis',
#        'donor_tumour_stage_at_diagnosis',               'Histological_type',
#                             'IDH_status',                               nan,
#                              'FGFR2_mut',                   'Relapse_event',
#                       'Relapse_interval',                        'OS_event',
#                    'donor_survival_time'],
#       dtype='object', name='Gene_ID')

# %%
exp_df = data_df.loc[39:, :]
exp_df.set_index('Gene_ID', drop=True, inplace=True)
exp_df = exp_df.T.astype(float)
exp_df = exp_df.dropna(axis=1)
exp_df.shape
# Out:
# (182, 26740)

# %%
mut_file = 'Patients_Data/ICGC/ICGC_Mutations.xlsx'
raw_mut_df = MyLib.load_xls(mut_file, sheet_no=0, index_col=0)
print('Shape:', raw_mut_df.shape)
raw_mut_df = raw_mut_df[~raw_mut_df.index.duplicated(keep='first')]
print('Shape:', raw_mut_df.shape)
raw_mut_df.index = raw_mut_df.index.map(lambda x: x.replace('T',''))
raw_mut_df['KRAS'] = raw_mut_df['KRAS BRAF NRAS'].apply(lambda x:x if x=='KRAS' else np.nan)
raw_mut_df['BRAF'] = raw_mut_df['KRAS BRAF NRAS'].apply(lambda x:x if x=='BRAF' else np.nan)
raw_mut_df.columns
# Out:
# Shape: (234, 28)
# Shape: (233, 28)
# Index(['Tumor type 2', 'WES (Y=done, N-not done)',
#        'RNAseq(Y=done, N-not done)', 'Gender', 'Virus', 'HBV integration',
#        'PSC', 'Histology', 'overall survival (days)', 'T', 'N', 'M', 'Stage',
#        'Field1', 'IDH', 'BAP1', 'ARID1A', 'ARID1B', 'ARID2', 'PBRM1', 'FGFR2',
#        'FGFR2.1', 'SMAD4', 'KRAS BRAF NRAS', 'KRAS BRAF NRAS.1', 'TP53',
#        'CDKN2A', 'PIK3CA', 'KRAS', 'BRAF'],
#       dtype='object')

# %%
mutations = ['IDH', 'BAP1', 'PBRM1', 'ARID1A', 'KRAS', 'BRAF', 'SMAD4', 'FGFR2.1']
icgc_mut_df = pd.DataFrame(0, index=exp_df.index, columns=mutations)
ids = list(set(raw_mut_df.index.values).intersection(exp_df.index.values))
icgc_mut_df.loc[ids, mutations] = raw_mut_df.loc[ids, mutations]
icgc_mut_df = icgc_mut_df.rename(columns={'FGFR2.1':'FGFR2_MT', 'IDH':'IDH_MT', 'BAP1':'BAP1_MT', 'PBRM1':'PBRM1_MT', 'ARID1A':'ARID1A_MT', 'KRAS':'KRAS_MT', 'BRAF':'BRAF_MT', 'SMAD4':'SMAD4_MT'})
icgc_mut_df = icgc_mut_df.fillna(0)
icgc_mut_df[icgc_mut_df != 0] = 1

# %%
muts_l = ['IDH_MT', 'BAP1_MT', 'FGFR2_MT']
icgc_mut_df['mutation_R3'] = (icgc_mut_df['IDH_MT'] | icgc_mut_df['BAP1_MT'] | icgc_mut_df['FGFR2_MT']).astype(int)
icgc_mut_df['mutation_R3'] = icgc_mut_df['mutation_R3'].replace({0: 'WT', 1: 'MT'})

R4_muts_l = ['KRAS_MT', 'BRAF_MT', 'SMAD4_MT']
icgc_mut_df['mutation_R4'] = (icgc_mut_df['KRAS_MT'] | icgc_mut_df['BRAF_MT'] | icgc_mut_df['SMAD4_MT']).astype(int)
icgc_mut_df['mutation_R4'] = icgc_mut_df['mutation_R4'].replace({0: 'WT', 1: 'MT'})
icgc_mut_df.shape
# Out:
# (182, 10)

# %%
Utils.piechart(icgc_mut_df[['IDH_MT', 'BAP1_MT', 'FGFR2_MT']])

# %% [markdown]
# ## ssGSEA for R3 Signature

# %% [markdown]
# Apply ssGSEA on R3 features

# %%
cluster = 'R3'
R3_features_filtered = list(set(R3_features).intersection(exp_df.columns))
print('Shared features:', len(R3_features_filtered))
# Out:
# Shared features: 50

# %%
ssgsea_df = MyRFunctions.ssgsea(exp_df.T, R3_features_filtered)
# Out:
# [1] "Calculating ranks..."
# [1] "Calculating absolute values from ranks..."
# [1] "Normalizing..."

# %%
icgc_R3_ssgsea_df = zscore(ssgsea_df)
icgc_R3_ssgsea_df
# Out:
#          ssGSEA
# BD101  1.215253
# BD104 -0.031344
# BD105  1.061743
# BD109  1.001801
# BD10  -0.264005
# ...         ...
# BD91   0.264046
# BD92   1.102429
# BD95   0.788191
# BD97   0.169895
# BD9    0.443031
#
# [182 rows x 1 columns]

# %%
MyVisualization.plot_distribution(icgc_R3_ssgsea_df['ssGSEA'])

# %%
R3_threshold = np.percentile(icgc_R3_ssgsea_df['ssGSEA'], 75)
print('ssGSEA enrichment cut-off:', R3_threshold)
icgc_R3_ssgsea_df['High_ssGSEA'] = (icgc_R3_ssgsea_df['ssGSEA'] >= R3_threshold).astype(int)
ssgsea_dic = {0: 'Rest', 1: 'R3 Enriched'}
icgc_R3_ssgsea_df['High_ssGSEA'] = icgc_R3_ssgsea_df['High_ssGSEA'].replace(ssgsea_dic)
# Out:
# ssGSEA enrichment cut-off: 0.7903044270946068

# %%
df = pd.concat([icgc_R3_ssgsea_df, icgc_mut_df, exp_df], axis=1)
df = df.sort_values(by=['ssGSEA'], ascending=False)

# %% [markdown]
# ## R3 Mutation Signature comparison

# %%
color = {'WT': control_color, 'MT': R3_color}
x = 'mutation_R3'
y = 'ssGSEA'
y_label = 'ssGSEA Score'
x_label = 'ICGC Cohort'
title = f'R3 Signature (n={len(R3_features_filtered)})'
print(f'Mutations: {muts_l}')
Utils.compare_visualize_cat_features(df, x=x, y=y, color_dic=color, y_label=y_label, x_label=x_label, title=title, label_newline=False,title_fontsize=7, tick_fontsize=6, label_fontsize=7.5, ylim_top=3, ylim_bottom=-3, ytick_step=1.5, figure_width=1.4, figure_height=1.5, test='ranksum', save_figure=True)
# Out:
# Mutations: ['IDH_MT', 'BAP1_MT', 'FGFR2_MT']
# ranksum p-value=4.729473572906345e-09
# There is a significant association.

# %%
title = 'ICGC Cohort'
Utils.split_mutation_profiles(df, R3_muts_l=muts_l, R4_muts_l=R4_muts_l, color_dic=color_dic, title=title, file_name='ICGC_R3')
# Out:
# Mutation_Signature  R3  R3 & R4  R4  WT
# High_ssGSEA
# R3 Enriched         17        1   6  22
# Rest                 7        2  41  86
# -------------------
# High_ssGSEA         R3 Enriched  Rest
# Mutation_Signature
# R4                            7    43
# WT                           39    93
# Odds Ratio: 0.3881932021466905
# P-value: 0.035726385493914346
# There is a significant association between R4 and WT
# ===============================
# {('R4', 'WT'): 0.035726385493914346}
# -------------------
# High_ssGSEA         R3 Enriched  Rest
# Mutation_Signature
# R3                           18     9
# WT                           28   127
# Odds Ratio: 9.071428571428571
# P-value: 8.274061583083273e-07
# There is a significant association between R3 and WT
# ===============================
# {('R3', 'WT'): 8.274061583083273e-07}
# -------------------
# p-value= [8.274061583083273e-07, 0.035726385493914346]

# %% [markdown]
# ## ICGC - HNF1B

# %%
color = {'Rest':control_color, 'R3 Enriched':R3_color}
x = 'High_ssGSEA'
y = 'HNF1B'
y_label = 'HNF1B mRNA Expression'
title = 'ICGC Cohort'
Utils.compare_visualize_cat_features(df, x=x, y=y, color_dic=color, test='ranksum', y_label=y_label, title=title, label_newline=True, title_fontsize=8, ylim_top=200, ytick_step=50, title_height=1.0, tick_fontsize=7, label_fontsize=7.,figure_width=1.4, figure_height=1.5, save_figure=True)
# Out:
# ranksum p-value=2.5771797141722836e-14
# There is a significant association.

# %% [markdown]
# ## ICGC - SULT1A1

# %%
color = {'Rest': control_color, 'R3 Enriched':  R3_color}
x = 'High_ssGSEA'
y = 'SULT1A1'
y_label = 'SULT1A1 mRNA Expression'
title = 'ICGC Cohort'
Utils.compare_visualize_cat_features(df, x=x, y=y, color_dic=color, test='ranksum', y_label=y_label, label_newline=True, title=title, title_height=1.,title_fontsize=8, tick_fontsize=7, label_fontsize=7., ylim_top=400, ytick_step=100, figure_width=1.4, figure_height=1.5, save_figure=True)
# Out:
# ranksum p-value=5.646639150722362e-11
# There is a significant association.

# %% [markdown]
# ## ICGC R3 Survival

# %%
icgc_R3_ssgsea_df['R3_ssGSEA'] = icgc_R3_ssgsea_df['High_ssGSEA'].replace({'R3 Enriched':1, 'Rest': 0})
surv_df = ICGC_info_df[['donor_survival_time', 'OS_event']].dropna(axis=0, how='all').astype(float)
surv_df['Group'] = 0#'Low ssGSEA'
surv_df.loc[icgc_R3_ssgsea_df.loc[surv_df.index, 'R3_ssGSEA'] ==1, 'Group'] = 1#'High ssGSEA'
surv_df.columns
# Out:
# Index(['donor_survival_time', 'OS_event', 'Group'], dtype='object', name='Gene_ID')

# %%
colors_l = ['#a00000','#077f97']
labels = ['Low', ' High']
MyRFunctions.survival_analysis(surv_df[['donor_survival_time', 'OS_event']], surv_df[['Group']], group='Group', cur_title=f'ICGC Cohort Overal Survival ({cluster} signature ssGSEA score)', legend_lbls=labels, colors_elms=colors_l, plot_path=os.path.join(io_library.output_dir, f'ICGC_Overal_Survival_Plot_{cluster}.pdf'))
# Out:
# R[write to console]: Loading required package: usethis
# 0 119
# 1 42
# ------
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.4     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.1
# ✔ ggplot2   3.4.4     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# R[write to console]: data.table 1.14.8 using 1 threads (see ?getDTthreads).  Latest news: r-datatable.com
#
# R[write to console]: **********
# This installation of data.table has not detected OpenMP support. It should still work but in single-threaded mode.
# This is a Mac. Please read https://mac.r-project.org/openmp/. Please engage with Apple and ask them for support. Check r-datatable.com for updates, and our Mac instructions here: https://github.com/Rdatatable/data.table/wiki/Installation. After several years of many reports of installation problems on Mac, it's time to gingerly point out that there have been no similar problems on Windows or Linux.
# **********
#
# R[write to console]:
# Attaching package: ‘data.table’
#
#
# R[write to console]: The following objects are masked from ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
#
# R[write to console]: The following objects are masked from ‘package:dplyr’:
#
#     between, first, last
#
#
# R[write to console]: The following object is masked from ‘package:purrr’:
#
#     transpose
#
#
# R[write to console]: Loading required package: ggpubr
#
# R[write to console]:
# Attaching package: ‘survminer’
#
#
# R[write to console]: The following object is masked from ‘package:survival’:
#
#     myeloma
#
#
# R[write to console]: Loading required package: gridExtra
#
# R[write to console]:
# Attaching package: ‘gridExtra’
#
#
# R[write to console]: The following object is masked from ‘package:dplyr’:
#
#     combine
#
#
# R[write to console]:
# Attaching package: ‘egg’
#
#
# R[write to console]: The following object is masked from ‘package:ggpubr’:
#
#     ggarrange

# %% [markdown]
# ## ssGSEA for R4 Signature

# %%
cluster ='R4'
R4_features_filtered = sorted(set(R4_features).intersection(set(exp_df.T.index)))
print('Shared features:', len(R4_features_filtered))
# Out:
# Shared features: 48

# %%
ssgsea_df = MyRFunctions.ssgsea(exp_df.T, R4_features_filtered)
# Out:
# [1] "Calculating ranks..."
# [1] "Calculating absolute values from ranks..."
# [1] "Normalizing..."

# %%
icgc_R4_ssgsea_df = zscore(ssgsea_df)
icgc_R4_ssgsea_df.head()
# Out:
#          ssGSEA
# BD101 -0.088613
# BD104  0.812237
# BD105 -1.300263
# BD109 -0.522945
# BD10   0.623142

# %%
MyVisualization.plot_distribution(icgc_R4_ssgsea_df['ssGSEA'])

# %%
R4_threshold = np.percentile(icgc_R4_ssgsea_df['ssGSEA'], 75)
print('Enrichment cut-off:', R4_threshold) 
icgc_R4_ssgsea_df['High_ssGSEA'] = (icgc_R4_ssgsea_df['ssGSEA'] >= R4_threshold).astype(int)
icgc_R4_ssgsea_df['High_ssGSEA'] = icgc_R4_ssgsea_df['High_ssGSEA'].replace({0: 'Rest', 1: 'R4 Enriched'})
icgc_R4_ssgsea_df.head(10)
# Out:
# Enrichment cut-off: 0.6845142049575184
#          ssGSEA  High_ssGSEA
# BD101 -0.088613         Rest
# BD104  0.812237  R4 Enriched
# BD105 -1.300263         Rest
# BD109 -0.522945         Rest
# BD10   0.623142         Rest
# BD111  0.468397         Rest
# BD112  0.721878  R4 Enriched
# BD114  0.406165         Rest
# BD115 -0.947820         Rest
# BD117 -0.906098         Rest

# %%
df = pd.concat([icgc_R4_ssgsea_df, icgc_mut_df], axis=1)
# MyLib.save_csv(df, 'FU_CCA_R3_ssGSEA_mutations_RNA.csv')

# %% [markdown]
# ## R4 Mutation Signature comparison

# %%
color = {'WT': control_color, 'MT': R4_color}
x = 'mutation_R4'
y = 'ssGSEA'
y_label = 'ssGSEA Score'
x_label = 'ICGC Cohort'
title = f'R4 Signature (n={len(R4_features_filtered)})'
print(f'Mutations: {R4_muts_l}')
Utils.compare_visualize_cat_features(df, x=x, y=y, color_dic=color, y_label=y_label, x_label=x_label, title=title,
                                     label_newline=False, title_fontsize=7, tick_fontsize=6, label_fontsize=7.5,
                                     ylim_top=3., ytick_step=1.5, figure_width=1.4, figure_height=1.5,
                                     test='ranksum', save_figure=True)
# Out:
# Mutations: ['KRAS_MT', 'BRAF_MT', 'SMAD4_MT']
# ranksum p-value=1.0703491869019606e-07
# There is a significant association.

# %%
title = 'ICGC Cohort'
Utils.split_mutation_profiles(df, R3_muts_l=muts_l, R4_muts_l=R4_muts_l, color_dic=color_dic, title=title, file_name='ICGC_R4')
# Out:
# Mutation_Signature  R3  R3 & R4  R4  WT
# High_ssGSEA
# R4 Enriched          3        0  25  18
# Rest                21        3  22  90
# -------------------
# High_ssGSEA         R4 Enriched  Rest
# Mutation_Signature
# R4                           25    25
# WT                           21   111
# Odds Ratio: 5.285714285714286
# P-value: 6.49222767083459e-06
# There is a significant association between R4 and WT
# ===============================
# {('R4', 'WT'): 6.49222767083459e-06}
# -------------------
# High_ssGSEA         R4 Enriched  Rest
# Mutation_Signature
# R3                            3    24
# WT                           43   112
# Odds Ratio: 0.32558139534883723
# P-value: 0.09154745063096964
# There is no significant association between R3 and WT
# ===============================
# {('R3', 'WT'): 0.09154745063096964}
# -------------------
# p-value= [0.09154745063096964, 6.49222767083459e-06]

# %% [markdown]
# ## ICGC R4 Survival

# %%
icgc_R4_ssgsea_df['R4_ssGSEA'] = icgc_R4_ssgsea_df['High_ssGSEA'].replace({'R4 Enriched':1, 'Rest': 0})
surv_df = ICGC_info_df[['donor_survival_time', 'OS_event']].dropna(axis=0, how='all').astype(float)
surv_df['Group'] = 0#'Low ssGSEA'
surv_df.loc[icgc_R4_ssgsea_df.loc[surv_df.index, 'R4_ssGSEA'] ==1, 'Group'] = 1#'High ssGSEA'
print(surv_df.shape)
surv_df.columns
# Out:
# (161, 3)
# Index(['donor_survival_time', 'OS_event', 'Group'], dtype='object', name='Gene_ID')

# %%
colors_l = ['#a00000','#077f97']
labels = ['Low', ' High']
MyRFunctions.survival_analysis(surv_df[['donor_survival_time', 'OS_event']], surv_df[['Group']], group='Group',cur_title=f'ICGC Cohort Overal Survival ({cluster} signature ssGSEA score)', legend_lbls=labels, colors_elms=colors_l, plot_path=os.path.join(io_library.output_dir, f'ICGC_Overal_Survival_Plot_{cluster}.pdf'))
# Out:
# 0 122
# 1 39
# ------

# %% [markdown]
# ## CSGALNACT1

# %%
df = exp_df[['CSGALNACT1']].copy()
df['Group'] = (icgc_mut_df['BAP1_MT'] | icgc_mut_df['FGFR2_MT']).astype(int)
df['Group'] = df['Group'].replace({0: 'WT', 1: 'BAP1/FGFR2'})
df.columns
# Out:
# Index(['CSGALNACT1', 'Group'], dtype='object', name='Gene_ID')

# %%
df.shape
# Out:
# (182, 2)

# %%
cur_color_dic = {'WT':'#c9c7c7', 'BAP1/FGFR2': '#A00000'}
x = 'Group'
gene = 'CSGALNACT1'
title = 'ICGC Cohort'
Utils.compare_visualize_cat_features(df, x=x, y=gene, color_dic=cur_color_dic, y_label=f'{gene} mRNA Expression', test='ranksum', title=title, title_height=1.,title_fontsize=7, figure_width=1.2, figure_height=1.4, label_fontsize=6, ylim_top=150, ytick_step=50, label_newline=True, save_figure=True)
# Out:
# ranksum p-value=0.007019984732525212
# There is a significant association.

# %% [markdown]
# ## TP63

# %% [markdown]
# Investigate the top expressed genes in cluster C6 of the CRISPR clustering.

# %%
C6_features = ['FAT2', 'CASP1', 'IRF6', 'KRT15', 'SERPINB13']

# %%
ssgsea_df = MyRFunctions.ssgsea(exp_df.T, C6_features)
# Out:
# [1] "Calculating ranks..."
# [1] "Calculating absolute values from ranks..."
# [1] "Normalizing..."

# %%
icgc_C6_ssgsea_df = zscore(ssgsea_df)
icgc_C6_ssgsea_df
# Out:
#          ssGSEA
# BD101 -0.786086
# BD104  0.788500
# BD105 -0.421846
# BD109 -0.565191
# BD10   0.085113
# ...         ...
# BD91  -0.213450
# BD92   0.252251
# BD95  -0.259156
# BD97   0.368555
# BD9   -0.345185
#
# [182 rows x 1 columns]

# %%
df = pd.concat([icgc_C6_ssgsea_df, exp_df[['TP63']]], axis=1)
df.columns
# Out:
# Index(['ssGSEA', 'TP63'], dtype='object')

# %%
x = 'TP63'
y = 'ssGSEA'
points_color = '#6b676e'
line_color = '#C1914B'

MyVisualization.reg_plot(data_df=df, x_col=x, y_col=y, title=f'ICGC Cohort ($n$={df.shape[0]})', points_color_code=points_color, line_color_code=line_color, ylabel='ssGSEA Score',  xlabel=f"{x} mRNA Expression" , marker='o', title_height=1.1, text_height=.95, ylim_top=6, xlim_right=65, xtick_step=13, file_name=f'ICGC_{x}_{y}')
# Out:
# p-value:  8.70844850134406e-12

# %% [markdown]
# ### Patients stratification

# %%
tp63_df = exp_df[['TP63']].copy()
MyVisualization.plot_distribution(tp63_df['TP63'], title='ICGC Cohort TP63 mRNA Expression', x_vline=10)

# %%
tp63_thr= 10
top_tp63_df = tp63_df[tp63_df['TP63']>tp63_thr][['TP63']]
top_tp63_df.shape
# Out:
# (8, 1)

# %%
percentage = (top_tp63_df.shape[0]/df.shape[0])*100
print('Percentage of patients with high expression of TP63:', round(percentage, 2))
# Out:
# Percentage of patients with high expression of TP63: 4.4

# %%
tp63_df['TP63_High'] = (tp63_df['TP63']>tp63_thr).astype(int)
tp63_df['TP63_High']
# Out:
# BD101    0
# BD104    0
# BD105    0
# BD109    0
# BD10     0
#         ..
# BD91     0
# BD92     0
# BD95     0
# BD97     0
# BD9      0
# Name: TP63_High, Length: 182, dtype: int64

# %% [markdown]
# ### Save TP63 Results

# %%
tp63_all_df = pd.concat([tp63_df['TP63_High'], df['ssGSEA']], axis=1)
tp63_all_df
# Out:
#        TP63_High    ssGSEA
# BD101          0 -0.786086
# BD104          0  0.788500
# BD105          0 -0.421846
# BD109          0 -0.565191
# BD10           0  0.085113
# ...          ...       ...
# BD91           0 -0.213450
# BD92           0  0.252251
# BD95           0 -0.259156
# BD97           0  0.368555
# BD9            0 -0.345185
#
# [182 rows x 2 columns]

# %%
MyLib.save_csv(tp63_all_df, f'ICGC_TP63_mRNA_status_ssGSEA.csv')
# Out:
# File  Remaining_Analyses/output_figs_patients/ICGC_TP63_mRNA_status_ssGSEA.csv saved, shape: (182, 2)

# %% [markdown]
# ## Save Results

# %%
icgc_R3_ssgsea_df
# Out:
#          ssGSEA  High_ssGSEA  R3_ssGSEA
# BD101  1.215253  R3 Enriched          1
# BD104 -0.031344         Rest          0
# BD105  1.061743  R3 Enriched          1
# BD109  1.001801  R3 Enriched          1
# BD10  -0.264005         Rest          0
# ...         ...          ...        ...
# BD91   0.264046         Rest          0
# BD92   1.102429  R3 Enriched          1
# BD95   0.788191         Rest          0
# BD97   0.169895         Rest          0
# BD9    0.443031         Rest          0
#
# [182 rows x 3 columns]

# %%
icgc_R4_ssgsea_df
# Out:
#          ssGSEA  High_ssGSEA  R4_ssGSEA
# BD101 -0.088613         Rest          0
# BD104  0.812237  R4 Enriched          1
# BD105 -1.300263         Rest          0
# BD109 -0.522945         Rest          0
# BD10   0.623142         Rest          0
# ...         ...          ...        ...
# BD91   0.355801         Rest          0
# BD92  -0.772299         Rest          0
# BD95   0.138201         Rest          0
# BD97   0.993659  R4 Enriched          1
# BD9    0.409590         Rest          0
#
# [182 rows x 3 columns]

# %%
d1 = icgc_R3_ssgsea_df[['ssGSEA', 'High_ssGSEA']]
d1 = d1.rename(columns={'ssGSEA':'R3_ssGSEA', 'High_ssGSEA':f'R3_status (thr={round(R3_threshold,3)})'})
d2 = icgc_R4_ssgsea_df[['ssGSEA', 'High_ssGSEA']]
d2 = d2.rename(columns={'ssGSEA':'R4_ssGSEA', 'High_ssGSEA':f'R4_status (thr={round(R4_threshold,3)}'})
df = pd.concat([d1, d2, icgc_mut_df[['mutation_R3', 'mutation_R4']], tp63_df['TP63_High']], axis=1)
MyLib.save_csv(df, 'ICGC_ssGSEA_mutations.csv')
# df = pd.concat([d1, d2, icgc_mut_df, exp_df], axis=1)
# MyLib.save_csv(df, 'ICGC_ssGSEA_mutations_RNA.csv')
# Out:
# File  Remaining_Analyses/output_figs_patients/ICGC_ssGSEA_mutations.csv saved, shape: (182, 7)

# %% [markdown]
# # FU-CCA dataset RNA
#
# Select samples that have both RNA-seq and mutation status.

# %%
FU_CCA_dataset_file = 'Patients_Data/FU-CCA/Supplementary_Table_1 (Contains RNASEQ).xlsx'
supp = pd.ExcelFile(os.path.join(io_library.input_dir, FU_CCA_dataset_file))

raw_info_df = supp.parse(supp.sheet_names[1])
raw_info_df['Tumor (T) RNA-seq ID'] = raw_info_df['Tumor (T) RNA-seq ID'].apply(lambda x: x.replace('_', '-').strip() if not pd.isna(x) else x)
raw_info_df['Patient No.'] = raw_info_df['Patient No.'].apply(lambda x: x.strip())
patient_rna_id_df = raw_info_df[['Patient No.', 'Tumor (T) RNA-seq ID']].dropna(axis=0)


mut_df = supp.parse(supp.sheet_names[2])
mut_df['Patient No.'] = mut_df['Patient No.'].apply(lambda x: x.strip())
mut_df.set_index('Patient No.', drop=True, inplace=True)
indices = sorted(set(mut_df.index).intersection(patient_rna_id_df['Patient No.']))
fu_cca_mut_df = mut_df.loc[indices, ['IDH1', 'IDH2', 'BAP1', 'PBRM1', 'ARID1A', 'KRAS', 'SMAD4']].copy()
fu_cca_mut_df.columns = ['IDH1_MT', 'IDH2_MT', 'BAP1_MT', 'PBRM1_MT', 'ARID1A_MT', 'KRAS_MT','SMAD4_MT']
temp_df = patient_rna_id_df[patient_rna_id_df['Patient No.'].isin(indices)]
ids = dict(zip(temp_df['Tumor (T) RNA-seq ID'], temp_df['Patient No.']))

fusion_df = supp.parse(supp.sheet_names[11])
fusion_df.set_index('sample', drop=True, inplace=True)
fusion_df['LeftGene'] = fusion_df['LeftGene'].apply(lambda x: x.strip())
fusion_df['RightGene'] = fusion_df['RightGene'].apply(lambda x: x.strip())
fusion_df = fusion_df[(fusion_df['LeftGene']=='FGFR2') | (fusion_df['RightGene']=='FGFR2')]
fusion_ids = temp_df[temp_df['Tumor (T) RNA-seq ID'].isin(fusion_df.index)]['Patient No.'].tolist()
fu_cca_mut_df['FGFR2_MT'] = 0
fu_cca_mut_df.loc[fusion_ids, 'FGFR2_MT'] = 'Fusion'

raw_exp_df = supp.parse(supp.sheet_names[5])
raw_exp_df = raw_exp_df.rename(columns={'RNA-seq ID':'Gene'})
raw_exp_df.set_index('Gene', drop=True, inplace=True)
exp_df = raw_exp_df[temp_df['Tumor (T) RNA-seq ID']]
exp_df = exp_df.rename(columns={col:ids[col] for col in exp_df.columns})
exp_df = exp_df.T.astype(float)
exp_df = exp_df.dropna(axis=1)
exp_df = exp_df.T[~exp_df.T.index.duplicated(keep='first')] # Dataset contains duplicate genes
print('mRNA with mutation data shape', exp_df.shape)

ids = dict(zip(patient_rna_id_df['Tumor (T) RNA-seq ID'], patient_rna_id_df['Patient No.']))
all_exp_df = raw_exp_df[patient_rna_id_df['Tumor (T) RNA-seq ID']]
all_exp_df = all_exp_df.rename(columns={col:ids[col] for col in all_exp_df.columns})
all_exp_df = all_exp_df.T.astype(float)
all_exp_df = all_exp_df.dropna(axis=1)
all_exp_df = all_exp_df.T[~all_exp_df.T.index.duplicated(keep='first')]# dataset contains duplicate genes
print('mRNA data shape', all_exp_df.shape)

info_df = raw_info_df.set_index('Patient No.', drop=True)
info_df = info_df[info_df.index.isin(all_exp_df.columns)]
# Out:
# mRNA with mutation data shape (12666, 94)
# mRNA data shape (12666, 126)

# %% [markdown]
# Add columns for mutation signatures

# %%
fu_cca_mut_df = fu_cca_mut_df.fillna(0)
fu_cca_mut_df[fu_cca_mut_df != 0] = 1
muts_l = ['IDH1_MT','IDH2_MT', 'BAP1_MT', 'FGFR2_MT']
fu_cca_mut_df['mutation_R3'] = (fu_cca_mut_df['IDH1_MT'] | fu_cca_mut_df['IDH2_MT'] | fu_cca_mut_df['BAP1_MT'] | fu_cca_mut_df['FGFR2_MT']).astype(int)
fu_cca_mut_df['mutation_R3'] = fu_cca_mut_df['mutation_R3'].replace({0: 'WT', 1: 'MT'})

R4_muts_l= ['KRAS_MT', 'SMAD4_MT'] 
fu_cca_mut_df['mutation_R4'] = (fu_cca_mut_df['KRAS_MT'] | fu_cca_mut_df['SMAD4_MT']).astype(int)
fu_cca_mut_df['mutation_R4'] = fu_cca_mut_df['mutation_R4'].replace({0: 'WT', 1: 'MT'})
fu_cca_mut_df.head(10)
# Out:
#             IDH1_MT IDH2_MT BAP1_MT PBRM1_MT ARID1A_MT KRAS_MT SMAD4_MT  \
# Patient No.
# CCA#101           0       0       0        0         0       0        0
# CCA#102           0       0       0        0         0       0        0
# CCA#103           0       0       0        0         0       1        1
# CCA#105           0       0       0        0         0       0        0
# CCA#110           0       0       0        0         0       0        0
# CCA#112           0       0       0        1         0       0        0
# CCA#115           0       0       0        0         0       0        0
# CCA#116           0       0       0        0         0       0        0
# CCA#119           0       0       0        0         0       0        0
# CCA#120           0       0       1        0         0       0        0
#
#             FGFR2_MT mutation_R3 mutation_R4
# Patient No.
# CCA#101            0          WT          WT
# CCA#102            0          WT          WT
# CCA#103            0          WT          MT
# CCA#105            0          WT          WT
# CCA#110            0          WT          WT
# CCA#112            0          WT          WT
# CCA#115            0          WT          WT
# CCA#116            0          WT          WT
# CCA#119            0          WT          WT
# CCA#120            1          MT          WT

# %%
Utils.piechart(fu_cca_mut_df[['IDH1_MT', 'IDH2_MT', 'BAP1_MT', 'FGFR2_MT']])

# %% [markdown]
# ## ssGSEA for R3 Signature

# %% [markdown]
# Among the R3 features, there are 12 genes that are not included in the dataset:
#  ['PPBP', 'SPNS3', 'ALAS2', 'FXYD2', 'GUCA2B', 'DMBT1', 'KLHDC7A', 'SEC14L6', 'RHAG', 'PGBD5', 'SLC17A3', 'SLC35F3']

# %%
R3_features_filtered = sorted(set(R3_features).intersection(set(exp_df.index)))
print('Shared features:', len(R3_features_filtered))
# Out:
# Shared features: 34

# %%
ssgsea_df = MyRFunctions.ssgsea(exp_df, R3_features_filtered)
# Out:
# [1] "Calculating ranks..."
# [1] "Calculating absolute values from ranks..."
# [1] "Normalizing..."

# %%
FU_CCA_R3_ssgsea_df = zscore(ssgsea_df)
FU_CCA_R3_ssgsea_df.head(10)
# Out:
#           ssGSEA
# CCA#20 -1.704494
# CCA#21 -1.001702
# CCA#22 -1.354439
# CCA#23 -1.171998
# CCA#30  0.404393
# CCA#31 -0.142794
# CCA#32 -0.168574
# CCA#33  0.526238
# CCA#34  0.880163
# CCA#35  1.038444

# %%
MyVisualization.plot_distribution(FU_CCA_R3_ssgsea_df['ssGSEA'])

# %%
R3_threshold = np.percentile(FU_CCA_R3_ssgsea_df['ssGSEA'], 75)
print('Enrichment cut-off:', R3_threshold) 
FU_CCA_R3_ssgsea_df['High_ssGSEA'] = (FU_CCA_R3_ssgsea_df['ssGSEA'] >= R3_threshold).astype(int)
FU_CCA_R3_ssgsea_df['High_ssGSEA'] = FU_CCA_R3_ssgsea_df['High_ssGSEA'].replace({0: 'Rest', 1: 'R3 Enriched'})
FU_CCA_R3_ssgsea_df.head(10)
# Out:
# Enrichment cut-off: 0.9393713760375884
#           ssGSEA  High_ssGSEA
# CCA#20 -1.704494         Rest
# CCA#21 -1.001702         Rest
# CCA#22 -1.354439         Rest
# CCA#23 -1.171998         Rest
# CCA#30  0.404393         Rest
# CCA#31 -0.142794         Rest
# CCA#32 -0.168574         Rest
# CCA#33  0.526238         Rest
# CCA#34  0.880163         Rest
# CCA#35  1.038444  R3 Enriched

# %%
df = pd.concat([FU_CCA_R3_ssgsea_df, fu_cca_mut_df, exp_df.T], axis=1)
# MyLib.save_csv(df, 'FU_CCA_R3_ssGSEA_mutations_RNA.csv')
df = df.sort_values(by=['ssGSEA'], ascending=False)

# %% [markdown]
# ### R3 Mutation Signature comparison

# %%
color = {'WT': control_color, 'MT': R3_color}
x = 'mutation_R3'
y = 'ssGSEA'
y_label = 'ssGSEA Score'
x_label = 'FU-CCA Cohort'
title = f'R3 Signature (n={len(R3_features_filtered)})'
print('Mutations:', muts_l)
Utils.compare_visualize_cat_features(df, x=x, y=y, color_dic=color, y_label=y_label, x_label=x_label, title=title, label_newline=False,title_fontsize=7, tick_fontsize=6, label_fontsize=7.5, ylim_top=3., ylim_bottom=-3, ytick_step=1.5, figure_width=1.4, figure_height=1.5, test='ranksum', save_figure=True)
# Out:
# Mutations: ['IDH1_MT', 'IDH2_MT', 'BAP1_MT', 'FGFR2_MT']
# ranksum p-value=0.0011712982611074803
# There is a significant association.

# %%
title = 'FU-CCA Cohort'
Utils.split_mutation_profiles(df, R3_muts_l=muts_l, R4_muts_l=R4_muts_l, color_dic=color_dic, title=title, file_name='FU_CCA_R3')
# Out:
# Mutation_Signature  R3  R3 & R4  R4  WT
# High_ssGSEA
# R3 Enriched         13        0   0  11
# Rest                12        1  14  43
# -------------------
# High_ssGSEA         R3 Enriched  Rest
# Mutation_Signature
# R4                            0    15
# WT                           24    55
# Odds Ratio: 0.0
# P-value: 0.009888310914048255
# There is a significant association between R4 and WT
# ===============================
# {('R4', 'WT'): 0.009888310914048255}
# -------------------
# High_ssGSEA         R3 Enriched  Rest
# Mutation_Signature
# R3                           13    13
# WT                           11    57
# Odds Ratio: 5.181818181818182
# P-value: 0.0014134396149741522
# There is a significant association between R3 and WT
# ===============================
# {('R3', 'WT'): 0.0014134396149741522}
# -------------------
# p-value= [0.0014134396149741522, 0.009888310914048255]

# %% [markdown]
# ### HNF1B - RNA

# %%
color = {'Rest': control_color, 'R3 Enriched': R3_color}
x = 'High_ssGSEA'
y = 'HNF1B'
y_label = 'HNF1B mRNA Expression'
title = 'FU-CCA Cohort'
Utils.compare_visualize_cat_features(df, x=x, y=y, color_dic=color, test='ranksum', y_label=y_label, title=title, label_newline=True, title_fontsize=8, ylim_top=100, ytick_step=25, title_height=1.0, tick_fontsize=7, label_fontsize=7.,figure_width=1.3, figure_height=1.5, save_figure=True)
# Out:
# ranksum p-value=4.12738426761698e-09
# There is a significant association.

# %% [markdown]
# ### SULT1A1 - RNA

# %%
color = {'Rest': control_color, 'R3 Enriched': R3_color}
x = 'High_ssGSEA'
y = 'SULT1A1'
y_label = 'SULT1A1 mRNA Expression'
title = 'FU-CCA Cohort'
Utils.compare_visualize_cat_features(df, x=x, y=y, color_dic=color, test='ranksum', y_label=y_label, title=title, label_newline=True, title_fontsize=8, ylim_top=45, ytick_step=15, title_height=1.0, tick_fontsize=7, label_fontsize=7.,figure_width=1.2, figure_height=1.5, save_figure=True)
# Out:
# ranksum p-value=0.011916111052106743
# There is a significant association.

# %% [markdown]
# ### FU-CCA R3 Survival

# %% [markdown]
# Use the larger dataset that contains all samples with expression values and survival data.

# %%
all_exp_df.shape
# Out:
# (12666, 126)

# %%
cluster = 'R3'
ssgsea_df = MyRFunctions.ssgsea(all_exp_df, R3_features_filtered)
# Out:
# [1] "Calculating ranks..."
# [1] "Calculating absolute values from ranks..."
# [1] "Normalizing..."

# %%
all_FU_CCA_R3_ssgsea_df = zscore(ssgsea_df)
all_FU_CCA_R3_ssgsea_df.head(10)
# Out:
#           ssGSEA
# CCA#2  -0.050646
# CCA#4  -1.404275
# CCA#9  -1.450207
# CCA#11  0.210391
# CCA#12 -1.593675
# CCA#13 -1.028968
# CCA#14 -0.497135
# CCA#15 -0.814821
# CCA#20 -1.487285
# CCA#21 -0.791708

# %%
threshold = np.percentile(all_FU_CCA_R3_ssgsea_df['ssGSEA'], 75)
# threshold=0
print('R3 Enrichment cut-off:', threshold)
all_FU_CCA_R3_ssgsea_df['R3_ssGSEA'] = (all_FU_CCA_R3_ssgsea_df['ssGSEA'] >= threshold).astype(int)
# all_FU_CCA_R3_ssgsea_df['R3_ssGSEA'] = all_FU_CCA_R3_ssgsea_df['R3_ssGSEA'].replace({0: 'Rest', 1: 'R3 Enriched'})
# Out:
# R3 Enrichment cut-off: 0.9211864678207146

# %%
surv_df = info_df[['Overall survival(day)', 'Survival(1,dead;0,alive)']].dropna(axis=0, how='all').astype(float)
surv_df['Group'] = 0#'Low ssGSEA'
surv_df.loc[all_FU_CCA_R3_ssgsea_df.loc[surv_df.index, 'R3_ssGSEA'] ==1, 'Group'] = 1#'High ssGSEA'
surv_df.head()
# Out:
#              Overall survival(day)  Survival(1,dead;0,alive)  Group
# Patient No.
# CCA#2                       1216.0                       1.0      0
# CCA#4                        437.0                       1.0      0
# CCA#11                       222.0                       1.0      0
# CCA#12                       391.0                       1.0      0
# CCA#13                       170.0                       1.0      0

# %%
info_filtered_df = info_df.rename(columns={'Tumor size (cm)':'Tumor size', 'Preoperative CA19-9（U/ml）':'Preoperative CA19-9', 'Preoperative CEA（ng/ml）':'Preoperative CEA', 'TB, total bilirubin (µmol/L)':'TB total bilirubin', 'Perineural invasion (PNI)':'Perineural invasion', 'Lymphovascular invasion (LVI)':'Lymphovascular invasion'})# R cannot take -

# %%
cont_feats_cols = ['Age', 'Tumor size', 'Preoperative CA19-9', 'Preoperative CEA', 'TB total bilirubin']
cat_feats_cols = ['Gender', 'Anatomical classification', 'Histology', 'iCCA classification', 'HBsAg','Cholelithiasis', 'Jaundice', 'Type II diabetes', 'Hypertension', 'Presence of fluke infection', 'Perineural invasion', 'Lymphovascular invasion', 'eccStage', 'iccStage', ]#'Grade'

# %%
info_filtered_df['iCCA classification'] = info_filtered_df['iCCA classification'].fillna('other')
info_filtered_df['eccStage'] = info_filtered_df['eccStage'].fillna('other')
info_filtered_df['iccStage'] = info_filtered_df['iccStage'].fillna('other')
info_filtered_df['Preoperative CA19-9'] = info_filtered_df['Preoperative CA19-9'].replace('<0.6', 0.59)
info_filtered_df['Preoperative CA19-9'] = info_filtered_df['Preoperative CA19-9'].replace('>10000', 10001)

# %%
info_filtered_df[cont_feats_cols] = info_filtered_df[cont_feats_cols].replace('Unknown', np.nan)
info_filtered_df2= info_filtered_df[cont_feats_cols+cat_feats_cols].dropna()
info_filtered_df2, surv_filtered_df = Utils.match_rows_df(info_filtered_df2, surv_df)
info_filtered_df2.shape
# Out:
# (114, 19)

# %% [markdown]
# Only 114 out of 122 patients with survival data

# %% [markdown]
# #### Kaplan-Meier

# %%
colors_l = ['#a00000','#077f97']
labels = ['Low', ' High']
MyRFunctions.survival_analysis(surv_filtered_df[['Overall survival(day)', 'Survival(1,dead;0,alive)']], surv_filtered_df[['Group']], 'Group', f'FU-CCA Cohort Overal Survival ({cluster} ssGSEA score)', legend_lbls=labels, colors_elms=colors_l, plot_path=os.path.join(io_library.output_dir, f'FU_CCA_Overal_Survival_Plot_{cluster}.pdf'))
# Out:
# 0 83
# 1 31
# ------

# %% [markdown]
# #### Cox Regression

# %% [markdown]
# Assess the impact of ssGSEA scores while adjusting for other covariates, and demonstrating that they are not confounding the relationship between ssGSEA scores and survival.

# %%
cat_clinical_feats_df = Utils.create_onehot_encoding_columns(info_filtered_df2, cat_feats_cols)
# Out:
# Gender
# Reference level: Gender_Female
# ------
# Anatomical classification
# Reference level: Anatomical classification_hilar/perihilar
# ------
# Histology
# Reference level: Histology_eCCA
# ------
# iCCA classification
# Reference level: other
# ------
# HBsAg
# Reference level: Unknown
# ------
# Cholelithiasis
# Reference level: Cholelithiasis_No
# ------
# Jaundice
# Reference level: Jaundice_No
# ------
# Type II diabetes
# Reference level: Type II diabetes_No
# ------
# Hypertension
# Reference level: Hypertension_No
# ------
# Presence of fluke infection
# Reference level: Presence of fluke infection_No
# ------
# Perineural invasion
# Reference level: Unknown
# ------
# Lymphovascular invasion
# Reference level: Unknown
# ------
# eccStage
# Reference level: other
# ------
# iccStage
# Reference level: other
# ------

# %%
all_clinical_feats_df = pd.concat([all_FU_CCA_R3_ssgsea_df.loc[info_filtered_df2.index, ['ssGSEA']], info_filtered_df2[cont_feats_cols], cat_clinical_feats_df], axis=1)
all_clinical_feats_df = all_clinical_feats_df.rename(columns={'ssGSEA':'R3_ssGSEA'})
all_clinical_feats_df = all_clinical_feats_df.rename(columns={col: col.replace('-', '_') for col in all_clinical_feats_df.columns})# R cannot take -
all_clinical_feats_df = all_clinical_feats_df.rename(columns={col: col.replace(' ', '_') for col in all_clinical_feats_df.columns})# R cannot take space
all_clinical_feats_df = all_clinical_feats_df.rename(columns={col: col.replace('/', '_') for col in all_clinical_feats_df.columns})# R cannot take /
all_clinical_feats_df = all_clinical_feats_df.astype(float)

# %%
# MyLib.save_csv(surv_filtered_df, 'survival.csv')
# MyLib.save_csv(all_clinical_feats_df, 'all_clinical_feats_df.csv')

# %%
all_clinical_feats_df
# Out:
#              R3_ssGSEA   Age  Tumor_size  Preoperative_CA19_9  \
# Patient No.
# CCA#101       1.041364  71.0         4.0                 54.7
# CCA#102       0.153787  61.0         1.2                 11.9
# CCA#105       1.155743  62.0         3.3                  1.9
# CCA#11        0.210391  55.0         7.0                624.6
# CCA#110      -0.049067  62.0         4.5                233.7
# ...                ...   ...         ...                  ...
# CCA#92       -0.578241  56.0         4.0                171.0
# CCA#93        0.311062  65.0         4.0                414.5
# CCA#94        1.071198  61.0         5.0                  0.7
# CCA#95        1.256191  67.0         5.0                 10.0
# CCA#98        1.434210  69.0         2.5                 18.3
#
#              Preoperative_CEA  TB_total_bilirubin  Gender_Male  \
# Patient No.
# CCA#101                  3.40                11.4          0.0
# CCA#102                  2.00                 9.5          0.0
# CCA#105                  7.60                10.5          1.0
# CCA#11                   4.66               331.9          1.0
# CCA#110                  3.40                 7.1          0.0
# ...                       ...                 ...          ...
# CCA#92                   7.40                93.7          0.0
# CCA#93                   3.80                11.5          1.0
# CCA#94                   1.20                14.7          1.0
# CCA#95                   1.70                10.3          1.0
# CCA#98                   1.60                 6.0          1.0
#
#              Anatomical_classification_intrahepatic  Histology_iCCA  \
# Patient No.
# CCA#101                                         1.0             1.0
# CCA#102                                         1.0             1.0
# CCA#105                                         1.0             1.0
# CCA#11                                          0.0             0.0
# CCA#110                                         1.0             1.0
# ...                                             ...             ...
# CCA#92                                          0.0             0.0
# CCA#93                                          1.0             1.0
# CCA#94                                          1.0             1.0
# CCA#95                                          1.0             1.0
# CCA#98                                          1.0             1.0
#
#              iCCA_classification_Unknown  ...  eccStage_IIIA  eccStage_IIIB  \
# Patient No.                               ...
# CCA#101                              0.0  ...            0.0            0.0
# CCA#102                              1.0  ...            0.0            0.0
# CCA#105                              0.0  ...            0.0            0.0
# CCA#11                               0.0  ...            0.0            0.0
# CCA#110                              0.0  ...            0.0            0.0
# ...                                  ...  ...            ...            ...
# CCA#92                               0.0  ...            1.0            0.0
# CCA#93                               0.0  ...            0.0            0.0
# CCA#94                               0.0  ...            0.0            0.0
# CCA#95                               0.0  ...            0.0            0.0
# CCA#98                               0.0  ...            0.0            0.0
#
#              eccStage_IIIC  eccStage_IVB  iccStage_IA  iccStage_IB  \
# Patient No.
# CCA#101                0.0           0.0          0.0          0.0
# CCA#102                0.0           0.0          1.0          0.0
# CCA#105                0.0           0.0          0.0          0.0
# CCA#11                 0.0           1.0          0.0          0.0
# CCA#110                0.0           0.0          1.0          0.0
# ...                    ...           ...          ...          ...
# CCA#92                 0.0           0.0          0.0          0.0
# CCA#93                 0.0           0.0          1.0          0.0
# CCA#94                 0.0           0.0          1.0          0.0
# CCA#95                 0.0           0.0          1.0          0.0
# CCA#98                 0.0           0.0          1.0          0.0
#
#              iccStage_II  iccStage_IIIA  iccStage_IIIB  iccStage_IV
# Patient No.
# CCA#101              1.0            0.0            0.0          0.0
# CCA#102              0.0            0.0            0.0          0.0
# CCA#105              1.0            0.0            0.0          0.0
# CCA#11               0.0            0.0            0.0          0.0
# CCA#110              0.0            0.0            0.0          0.0
# ...                  ...            ...            ...          ...
# CCA#92               0.0            0.0            0.0          0.0
# CCA#93               0.0            0.0            0.0          0.0
# CCA#94               0.0            0.0            0.0          0.0
# CCA#95               0.0            0.0            0.0          0.0
# CCA#98               0.0            0.0            0.0          0.0
#
# [114 rows x 34 columns]

# %%
all_clinical_feats_df = all_clinical_feats_df.drop(['iCCA_classification_small_iBD', 'eccStage_IVB', 'Anatomical_classification_intrahepatic', 'iccStage_IV'], axis=1)#

# %%
MyRFunctions.find_collinearity(all_clinical_feats_df.drop(['Gender_Male'], axis=1), all_clinical_feats_df[['Gender_Male']]) # removed 'Grade'
# Out:
# Model :
# Gender_Male ~ R3_ssGSEA + Age + Tumor_size + Preoperative_CA19_9 +
#     Preoperative_CEA + TB_total_bilirubin + Histology_iCCA +
#     iCCA_classification_Unknown + iCCA_classification_large_iBD +
#     HBsAg_Negative + HBsAg_Positive + Cholelithiasis_Yes + Jaundice_Yes +
#     Type_II_diabetes_Yes + Hypertension_Yes + Presence_of_fluke_infection_Yes +
#     Perineural_invasion_No + Perineural_invasion_Yes + Lymphovascular_invasion_No +
#     Lymphovascular_invasion_Yes + eccStage_II + eccStage_IIIA +
#     eccStage_IIIB + eccStage_IIIC + iccStage_IA + iccStage_IB +
#     iccStage_II + iccStage_IIIA + iccStage_IIIB

# %%
coxph_mv_df = MyRFunctions.coxph_multivariate(surv_filtered_df[['Overall survival(day)', 'Survival(1,dead;0,alive)']], all_clinical_feats_df)
coxph_mv_df
# Out:
# R[write to console]: Loading required package: carData
#
# R[write to console]:
# Attaching package: ‘car’
#
#
# R[write to console]: The following object is masked from ‘package:dplyr’:
#
#     recode
#
#
# R[write to console]: The following object is masked from ‘package:purrr’:
#
#     some
# [1] "AIC of cox model:  654.18368094741"
# [1] "Proportional Hazards Assumption: "
#                                        chisq df           p
# R3_ssGSEA                        0.032498379  1 0.856938199
# Age                              0.177839433  1 0.673236610
# Tumor_size                       0.075840523  1 0.783015412
# Preoperative_CA19_9              2.308134871  1 0.128698395
# Preoperative_CEA                10.485697667  1 0.001203022
# TB_total_bilirubin               0.292462570  1 0.588646762
# Gender_Male                      0.111929869  1 0.737957615
# Histology_iCCA                   0.693980256  1 0.404813839
# iCCA_classification_Unknown      0.005945078  1 0.938540546
# iCCA_classification_large_iBD    2.179480479  1 0.139861667
# HBsAg_Negative                   0.021872969  1 0.882425534
# HBsAg_Positive                   0.126962047  1 0.721602924
# Cholelithiasis_Yes               0.023747234  1 0.877529803
# Jaundice_Yes                     0.082913743  1 0.773386953
# Type_II_diabetes_Yes             1.150351141  1 0.283475656
# Hypertension_Yes                 0.145575334  1 0.702800105
# Presence_of_fluke_infection_Yes  0.023237421  1 0.878841289
# Perineural_invasion_No           0.685066711  1 0.407847461
# Perineural_invasion_Yes          0.583387115  1 0.444987734
# Lymphovascular_invasion_No       1.120746238  1 0.289757826
# Lymphovascular_invasion_Yes      1.211540905  1 0.271027164
# eccStage_II                      0.110708404  1 0.739339065
# eccStage_IIIA                    0.120601139  1 0.728383419
# eccStage_IIIB                    4.144960897  1 0.041758620
# eccStage_IIIC                   10.652320085  1 0.001099329
# iccStage_IA                      0.080719513  1 0.776324708
# iccStage_IB                      2.313251704  1 0.128275454
# iccStage_II                      0.356414916  1 0.550504073
# iccStage_IIIA                    0.201550927  1 0.653471884
# iccStage_IIIB                    4.483998654  1 0.034213584
# GLOBAL                          42.641231048 30 0.062998735
#                            Variable      coef exp(coef)  se(coef)         z  \
# 0                         R3_ssGSEA -0.485579  0.615341  0.177199 -2.740305
# 1       iCCA_classification_Unknown  1.376551  3.961215  0.495573  2.777697
# 2                      Jaundice_Yes -1.933636  0.144621  0.757236 -2.553547
# 3               Preoperative_CA19_9  0.000206  1.000206   0.00009  2.293349
# 4                TB_total_bilirubin  0.006246  1.006265  0.002643  2.363426
# 5                       iccStage_IA -3.253716   0.03863  1.531377   -2.1247
# 6                       iccStage_IB   -2.7784  0.062138   1.52254 -1.824845
# 7                     eccStage_IIIC -2.566303  0.076819  1.508452 -1.701282
# 8                     iccStage_IIIA -2.702756  0.067021  1.558146 -1.734598
# 9                     iccStage_IIIB -3.168358  0.042073  1.769822 -1.790213
# 10                      Gender_Male  0.494369  1.639463  0.292241  1.691646
# 11                      iccStage_II -2.195591  0.111293  1.474584 -1.488956
# 12                      eccStage_II -2.003843  0.134816  1.342487 -1.492635
# 13                    eccStage_IIIB -2.030091  0.131324  1.426601 -1.423027
# 14                   HBsAg_Negative -1.418912  0.241977  1.313577  -1.08019
# 15                    eccStage_IIIA  -1.62538  0.196837  1.474536 -1.102299
# 16             Type_II_diabetes_Yes  0.374835  1.454752  0.481594  0.778322
# 17                              Age  0.013661  1.013754  0.018676  0.731464
# 18                 Hypertension_Yes  0.213254  1.237699  0.350883  0.607763
# 19       Lymphovascular_invasion_No -0.502543   0.60499  0.849023 -0.591907
# 20          Perineural_invasion_Yes   0.82858  2.290065  1.879794  0.440782
# 21           Perineural_invasion_No  0.384329  1.468629  1.927913   0.19935
# 22      Lymphovascular_invasion_Yes -0.072357  0.930199  0.877951 -0.082416
# 23                   Histology_iCCA  0.298518   1.34786  2.058427  0.145023
# 24               Cholelithiasis_Yes  0.096511  1.101322  0.352944  0.273446
# 25                 Preoperative_CEA  0.000728  1.000728  0.010359  0.070234
# 26                       Tumor_size  0.025296  1.025619  0.070461  0.359006
# 27                   HBsAg_Positive -0.333309  0.716549  1.361145 -0.244874
# 28  Presence_of_fluke_infection_Yes  0.039818  1.040621  0.570913  0.069744
# 29    iCCA_classification_large_iBD -0.007723  0.992307  0.641113 -0.012046
#
#     Pr(>|z|) lower .95  upper .95  log_lower .95  log_upper .95   q-value
# 0   0.006138  0.434794   0.870859      -0.832883      -0.138276  0.092073
# 1   0.005475  1.499672  10.463107       0.405246       2.347855  0.092073
# 2   0.010663  0.032785   0.637959      -3.417791      -0.449482  0.106632
# 3   0.021828   1.00003   1.000383       0.000030       0.000383  0.130968
# 4   0.018107  1.001067   1.011491       0.001066       0.011425  0.130968
# 5   0.033612  0.001921   0.777033      -6.255160      -0.252272  0.168058
# 6   0.068024  0.003143   1.228415      -5.762525       0.205724    0.2474
# 7    0.08889  0.003995   1.477289      -5.522815       0.390209    0.2474
# 8   0.082812  0.003162   1.420706      -5.756666       0.351154    0.2474
# 9    0.07342  0.001311   1.350438      -6.637145       0.300429    0.2474
# 10  0.090713  0.924582   2.907084      -0.078413       1.067150    0.2474
# 11  0.136499  0.006184   2.002789      -5.085723       0.694541  0.314998
# 12  0.135533  0.009705   1.872703      -4.635069       0.627383  0.314998
# 13  0.154728  0.008017   2.151133      -4.826177       0.765995  0.331561
# 14  0.280058  0.018436   3.176088      -3.993475       1.155650  0.525108
# 15  0.270332  0.010939   3.541878      -4.515417       1.264657  0.525108
# 16  0.436379  0.566051   3.738717      -0.569072       1.318742  0.770081
# 17  0.464496  0.977318   1.051549      -0.022943       0.050264  0.774159
# 18  0.543344  0.622219   2.461992      -0.474464       0.900971  0.830869
# 19  0.553913  0.114567    3.19476      -2.166597       1.161512  0.830869
# 20   0.65937  0.057513  91.186694      -2.855748       4.512909  0.941958
# 21  0.841989  0.033564  64.262035      -3.394311       4.162969  0.976963
# 22  0.934316  0.166442   5.198635      -1.793110       1.648396  0.976963
# 23  0.884693  0.023851  76.169466      -3.735924       4.332961  0.976963
# 24   0.78451  0.551427   2.199585      -0.595246       0.788269  0.976963
# 25  0.944007  0.980614   1.021254      -0.019577       0.021032  0.976963
# 26   0.71959  0.893325   1.177504      -0.112805       0.163397  0.976963
# 27  0.806554  0.049732  10.324158      -3.001105       2.334487  0.976963
# 28  0.944398  0.339884   3.186066      -1.079152       1.158787  0.976963
# 29  0.990389  0.282442   3.486279      -1.264280       1.248835  0.990389

# %%
MyVisualization.forest_plot(coxph_mv_df, title='FU-CCA Cohort Multivariate Cox Regression')

# %%
coxph_uni_df = MyRFunctions.coxph_multivariate(surv_filtered_df, all_FU_CCA_R3_ssgsea_df.loc[info_filtered_df2.index, ['R3_ssGSEA']])
coxph_uni_df
# Out:
# [1] "AIC of cox model:  661.470883538003"
# [1] "Proportional Hazards Assumption: "
#                chisq df         p
# R3_ssGSEA 0.01447473  1 0.9042368
# GLOBAL    0.01447473  1 0.9042368
#     Variable      coef exp(coef)  se(coef)         z  Pr(>|z|) lower .95  \
# 0  R3_ssGSEA -1.177865  0.307936  0.305629 -3.853905  0.000116  0.169164
#
#   upper .95  log_lower .95  log_upper .95   q-value
# 0  0.560546      -1.776887      -0.578843  0.000116

# %% [markdown]
# ssGSEA is significant in both multivariate and univariate analyses. The hazard ratio of ssGSEA in the multivariate model differs slightly with the univariate model, indicating that other covariates have a minimal impact. This suggests that the relationship between ssGSEA scores and survival is not confounded by other covariates.

# %%
MyLib.save_csv(coxph_mv_df, 'FU_CCA_cox_mutlivariate_R3_ssGSEA.csv', index=False)
# Out:
# File  Remaining_Analyses/output_figs_patients/FU_CCA_cox_mutlivariate_R3_ssGSEA.csv saved, shape: (30, 11)

# %% [markdown]
# ## ssGSEA for R4 Signature

# %%
cluster = 'R4'
R4_features_filtered = sorted(set(R4_features).intersection(set(exp_df.index)))
print('Shared features:', len(R4_features_filtered))
# Out:
# Shared features: 30

# %%
ssgsea_df = MyRFunctions.ssgsea(exp_df, R4_features_filtered)
# Out:
# [1] "Calculating ranks..."
# [1] "Calculating absolute values from ranks..."
# [1] "Normalizing..."

# %%
FU_CCA_R4_ssgsea_df = zscore(ssgsea_df)
FU_CCA_R4_ssgsea_df.head(10)
# Out:
#           ssGSEA
# CCA#20  0.190771
# CCA#21  1.134242
# CCA#22 -0.346277
# CCA#23  1.971387
# CCA#30 -0.334695
# CCA#31  1.276996
# CCA#32  0.306986
# CCA#33 -0.265609
# CCA#34  0.654583
# CCA#35 -0.807681

# %%
MyVisualization.plot_distribution(FU_CCA_R4_ssgsea_df['ssGSEA'])

# %%
R4_threshold = np.percentile(FU_CCA_R4_ssgsea_df['ssGSEA'], 75)
print('Enrichment cut-off:', R4_threshold) 
FU_CCA_R4_ssgsea_df['High_ssGSEA'] = (FU_CCA_R4_ssgsea_df['ssGSEA'] > R4_threshold).astype(int)
FU_CCA_R4_ssgsea_df['High_ssGSEA'] = FU_CCA_R4_ssgsea_df['High_ssGSEA'].replace({0: 'Rest', 1: 'R4 Enriched'})
FU_CCA_R4_ssgsea_df.head(10)
# Out:
# Enrichment cut-off: 0.723840504313161
#           ssGSEA  High_ssGSEA
# CCA#20  0.190771         Rest
# CCA#21  1.134242  R4 Enriched
# CCA#22 -0.346277         Rest
# CCA#23  1.971387  R4 Enriched
# CCA#30 -0.334695         Rest
# CCA#31  1.276996  R4 Enriched
# CCA#32  0.306986         Rest
# CCA#33 -0.265609         Rest
# CCA#34  0.654583         Rest
# CCA#35 -0.807681         Rest

# %%
df_R4 = pd.concat([FU_CCA_R4_ssgsea_df, fu_cca_mut_df, exp_df.T], axis=1)
# MyLib.save_csv(df, 'FU_CCA_R3_ssGSEA_mutations_RNA.csv')
df_R4 = df_R4.sort_values(by=['ssGSEA'], ascending=False)

# %% [markdown]
# ### R4 Mutation Signature comparison

# %%
color = {'WT': control_color, 'MT': R4_color}
x = 'mutation_R4'
y = 'ssGSEA'
y_label = 'ssGSEA Score'
x_label = 'FU-CCA Cohort'
title = f'R4 Signature (n={len(R4_features_filtered)})'
print('Mutations:', R4_muts_l)
Utils.compare_visualize_cat_features(df_R4, x=x, y=y, color_dic=color, y_label=y_label, x_label=x_label, title=title, label_newline=False,title_fontsize=7, tick_fontsize=6, label_fontsize=7.5, ylim_top=3., ylim_bottom=-3, ytick_step=1.5, figure_width=1.4, figure_height=1.5, test='ranksum', save_figure=True)
# Out:
# Mutations: ['KRAS_MT', 'SMAD4_MT']
# ranksum p-value=0.000669123664952085
# There is a significant association.

# %%
title = 'FU-CCA Cohort'
Utils.split_mutation_profiles(df_R4, R3_muts_l=muts_l, R4_muts_l=R4_muts_l, color_dic=color_dic, title=title, file_name='FU_CCA_R4')
# Out:
# Mutation_Signature  R3  R3 & R4  R4  WT
# High_ssGSEA
# R4 Enriched          0        0   9  15
# Rest                25        1   5  39
# -------------------
# High_ssGSEA         R4 Enriched  Rest
# Mutation_Signature
# R4                            9     6
# WT                           15    64
# Odds Ratio: 6.4
# P-value: 0.0021260855395068717
# There is a significant association between R4 and WT
# ===============================
# {('R4', 'WT'): 0.0021260855395068717}
# -------------------
# High_ssGSEA         R4 Enriched  Rest
# Mutation_Signature
# R3                            0    26
# WT                           24    44
# Odds Ratio: 0.0
# P-value: 0.00013170172319320182
# There is a significant association between R3 and WT
# ===============================
# {('R3', 'WT'): 0.00013170172319320182}
# -------------------
# p-value= [0.00013170172319320182, 0.0021260855395068717]

# %% [markdown]
# ### FU-CCA R4 Survival

# %%
ssgsea_df = MyRFunctions.ssgsea(all_exp_df, R4_features_filtered)
# Out:
# [1] "Calculating ranks..."
# [1] "Calculating absolute values from ranks..."
# [1] "Normalizing..."

# %%
all_FU_CCA_R4_ssgsea_df = zscore(ssgsea_df)
all_FU_CCA_R4_ssgsea_df.head(10)
# Out:
#           ssGSEA
# CCA#2  -1.000193
# CCA#4  -1.404213
# CCA#9  -0.931623
# CCA#11  0.213938
# CCA#12  0.260116
# CCA#13  0.609697
# CCA#14 -0.024429
# CCA#15  1.359082
# CCA#20  0.066437
# CCA#21  1.006204

# %%
threshold = np.percentile(all_FU_CCA_R4_ssgsea_df['ssGSEA'], 75)
# threshold=0
print(f'{cluster} Enrichment cut-off:', threshold)
all_FU_CCA_R4_ssgsea_df['R4_ssGSEA'] = (all_FU_CCA_R4_ssgsea_df['ssGSEA'] >= threshold).astype(int)
# all_FU_CCA_R4_ssgsea_df['High_ssGSEA'] = all_FU_CCA_R4_ssgsea_df['R4_ssGSEA'].replace({0: 'Rest', 1: 'R4 Enriched'})
# Out:
# R4 Enrichment cut-off: 0.8131644524077938

# %%
surv_df = info_df[['Overall survival(day)', 'Survival(1,dead;0,alive)']].dropna(axis=0, how='all').astype(float)
surv_df['Group'] = 0#'Low ssGSEA'
surv_df.loc[all_FU_CCA_R4_ssgsea_df.loc[surv_df.index, 'R4_ssGSEA'] ==1, 'Group'] = 1#'High ssGSEA'
surv_df
# Out:
#              Overall survival(day)  Survival(1,dead;0,alive)  Group
# Patient No.
# CCA#2                       1216.0                       1.0      0
# CCA#4                        437.0                       1.0      0
# CCA#11                       222.0                       1.0      0
# CCA#12                       391.0                       1.0      0
# CCA#13                       170.0                       1.0      0
# ...                            ...                       ...    ...
# CCA#210                      388.0                       1.0      0
# CCA#211                      448.0                       1.0      1
# CCA#212                      276.0                       1.0      0
# CCA#216                       32.0                       1.0      0
# CCA#217                      272.0                       1.0      0
#
# [122 rows x 3 columns]

# %%
info_filtered_df2, surv_filtered_df = Utils.match_rows_df(info_filtered_df2, surv_df)
surv_filtered_df.shape
# Out:
# (114, 3)

# %% [markdown]
# #### Kaplan-Meier

# %%
colors_l = ['#a00000','#077f97']
labels = ['Low', ' High']
MyRFunctions.survival_analysis(surv_filtered_df[['Overall survival(day)', 'Survival(1,dead;0,alive)']], surv_filtered_df[['Group']], 'Group', f'FU-CCA Cohort Overal Survival ({cluster} ssGSEA score)', legend_lbls=labels, colors_elms=colors_l, plot_path=os.path.join(io_library.output_dir, f'FU_CCA_Overal_Survival_Plot_{cluster}.pdf'))
# Out:
# 0 86
# 1 28
# ------

# %% [markdown]
# #### Cox Regression

# %%
all_clinical_feats_df = pd.concat([all_FU_CCA_R4_ssgsea_df.loc[info_filtered_df2.index, ['ssGSEA']], info_filtered_df2[cont_feats_cols], cat_clinical_feats_df], axis=1)
all_clinical_feats_df = all_clinical_feats_df.rename(columns={'ssGSEA':'R4_ssGSEA'})
all_clinical_feats_df = all_clinical_feats_df.rename(columns={col: col.replace('-', '_') for col in all_clinical_feats_df.columns})# R cannot take -
all_clinical_feats_df = all_clinical_feats_df.rename(columns={col: col.replace(' ', '_') for col in all_clinical_feats_df.columns})# R cannot take space
all_clinical_feats_df = all_clinical_feats_df.rename(columns={col: col.replace('/', '_') for col in all_clinical_feats_df.columns})# R cannot take space
all_clinical_feats_df = all_clinical_feats_df.astype(float)

# %%
coxph_mv_df = MyRFunctions.coxph_multivariate(surv_filtered_df, all_clinical_feats_df)
coxph_mv_df
# Out:
# [1] "AIC of cox model:  650.785585643258"
# [1] "Proportional Hazards Assumption: "
#                                               chisq df           p
# R4_ssGSEA                               0.793675778  1 0.372990960
# Age                                     0.044848546  1 0.832282766
# Tumor_size                              0.112039305  1 0.737834255
# Preoperative_CA19_9                     1.693087244  1 0.193194502
# Preoperative_CEA                        9.480201740  1 0.002077011
# TB_total_bilirubin                      0.464184073  1 0.495675006
# Gender_Male                             0.014550826  1 0.903986636
# Anatomical_classification_intrahepatic  1.440876599  1 0.229997540
# iCCA_classification_Unknown             0.002998867  1 0.956328147
# iCCA_classification_large_iBD           2.687879617  1 0.101114288
# HBsAg_Negative                          0.063594860  1 0.800901772
# HBsAg_Positive                          0.208580060  1 0.647882622
# Cholelithiasis_Yes                      0.005340326  1 0.941744416
# Jaundice_Yes                            0.012767008  1 0.910037543
# Type_II_diabetes_Yes                    2.469080290  1 0.116105845
# Hypertension_Yes                        0.132716140  1 0.715632309
# Presence_of_fluke_infection_Yes         0.010980295  1 0.916544902
# Perineural_invasion_No                  0.939624943  1 0.332374315
# Perineural_invasion_Yes                 0.822413301  1 0.364475517
# Lymphovascular_invasion_No              1.731315136  1 0.188243030
# Lymphovascular_invasion_Yes             1.767263212  1 0.183721141
# eccStage_II                             0.005528596  1 0.940728291
# eccStage_IIIA                           0.241260443  1 0.623297235
# eccStage_IIIB                           1.660053700  1 0.197596074
# eccStage_IIIC                           9.328511907  1 0.002256155
# iccStage_IA                             0.107116229  1 0.743451462
# iccStage_IB                             3.201972570  1 0.073549511
# iccStage_II                             0.297369997  1 0.585535914
# iccStage_IIIA                           0.035702584  1 0.850131007
# iccStage_IIIB                           4.611245547  1 0.031762955
# GLOBAL                                 40.659848506 30 0.092703706
#                                   Variable      coef exp(coef)  se(coef)  \
# 0              iCCA_classification_Unknown  1.720352  5.586492  0.477945
# 1                                R4_ssGSEA  0.582835  1.791109  0.178738
# 2                             Jaundice_Yes -2.479994  0.083744  0.785409
# 3                       TB_total_bilirubin  0.007447  1.007475  0.002646
# 4                              Gender_Male  0.652219  1.919796  0.284832
# 5                              eccStage_II -2.510388  0.081237  1.409076
# 6                            eccStage_IIIC -2.559019  0.077381  1.507554
# 7                              iccStage_IA  -2.14964  0.116526  1.561834
# 8                            eccStage_IIIB -2.012166  0.133699  1.412436
# 9                      Preoperative_CA19_9  0.000098  1.000098  0.000094
# 10                             iccStage_IB -1.554518  0.211291   1.57726
# 11                           eccStage_IIIA -1.440197  0.236881  1.507787
# 12                           iccStage_IIIA -1.523365  0.217977  1.567107
# 13                           iccStage_IIIB  -1.84277  0.158378  1.804767
# 14                        Hypertension_Yes  0.316025  1.371664  0.353361
# 15              Lymphovascular_invasion_No -0.661878  0.515881  0.828497
# 16                          HBsAg_Negative -0.906609  0.403892  1.317419
# 17                        Preoperative_CEA  0.007399  1.007427  0.010684
# 18  Anatomical_classification_intrahepatic  -1.26936  0.281012  2.066947
# 19                             iccStage_II -0.859644  0.423313  1.524403
# 20                      Cholelithiasis_Yes  0.149484  1.161235  0.345271
# 21                              Tumor_size  0.016559  1.016697  0.069151
# 22             Lymphovascular_invasion_Yes -0.236922  0.789052  0.876392
# 23           iCCA_classification_large_iBD -0.163013   0.84958  0.645004
# 24                                     Age    0.0066  1.006621  0.018842
# 25                    Type_II_diabetes_Yes  -0.08334  0.920039  0.480574
# 26                          HBsAg_Positive  0.154955  1.167605  1.381052
# 27         Presence_of_fluke_infection_Yes  0.037424  1.038133  0.576156
#
#            z  Pr(>|z|) lower .95  upper .95  log_lower .95  log_upper .95  \
# 0   3.599475  0.000319  2.189332  14.254988       0.783596       2.657107
# 1   3.260827  0.001111  1.261768    2.54252       0.232514       0.933156
# 2  -3.157585  0.001591  0.017964   0.390385      -4.019367      -0.940622
# 3   2.814122  0.004891  1.002263   1.012714       0.002260       0.012634
# 4   2.289836  0.022031  1.098514   3.355095       0.093958       1.210480
# 5  -1.781584  0.074817  0.005133    1.28576      -5.272126       0.251350
# 6  -1.697465  0.089609  0.004031    1.48547      -5.513770       0.395731
# 7  -1.376356  0.168711  0.005457   2.488047      -5.210778       0.911498
# 8  -1.424607  0.154271  0.008392   2.130075      -4.780490       0.756157
# 9   1.048748  0.294294  0.999915   1.000282      -0.000085       0.000282
# 10 -0.985581  0.324339  0.009601   4.649948      -4.645891       1.536856
# 11 -0.955173   0.33949  0.012334   4.549474      -4.395406       1.515012
# 12 -0.972087  0.331007  0.010104   4.702572      -4.594839       1.548110
# 13 -1.021057  0.307228  0.004608   5.443974      -5.380048       1.694509
# 14   0.89434   0.37114  0.686225   2.741757      -0.376550       1.008599
# 15  -0.79889  0.424354  0.101703   2.616785      -2.285703       0.961946
# 16  -0.68817  0.491346   0.03054   5.341388      -3.488703       1.675486
# 17  0.692581  0.488572  0.986551   1.028745      -0.013540       0.028339
# 18 -0.614123  0.539134   0.00489  16.147764      -5.320501       2.781782
# 19 -0.563922  0.572807  0.021335   8.399151      -3.847418       2.128131
# 20  0.432948  0.665053  0.590235   2.284625      -0.527234       0.826202
# 21  0.239464  0.810746   0.88783   1.164269      -0.118975       0.152094
# 22 -0.270338    0.7869  0.141618   4.396347      -1.954619       1.480774
# 23 -0.252732  0.800475   0.23998   3.007689      -1.427199       1.101172
# 24  0.350253  0.726149  0.970125   1.044491      -0.030330       0.043529
# 25 -0.173417  0.862324  0.358708   2.359778      -1.025247       0.858568
# 26    0.1122  0.910664  0.077937  17.492399      -2.551857       2.861766
# 27  0.064954  0.948211  0.335605   3.211276      -1.091821       1.166668
#
#      q-value
# 0   0.008928
# 1   0.014848
# 2   0.014848
# 3   0.034238
# 4   0.123373
# 5   0.349146
# 6   0.358435
# 7    0.52488
# 8    0.52488
# 9   0.678981
# 10  0.678981
# 11  0.678981
# 12  0.678981
# 13  0.678981
# 14  0.692794
# 15  0.742619
# 16  0.764315
# 17  0.764315
# 18  0.794513
# 19   0.80193
# 20  0.886737
# 21  0.908035
# 22  0.908035
# 23  0.908035
# 24  0.908035
# 25  0.928656
# 26  0.944393
# 27  0.948211

# %%
MyVisualization.forest_plot(coxph_mv_df, title='FU-CCA Cohort Multivariate Cox Regression', decimal_precision=3)

# %%
coxph_uni_df = MyRFunctions.coxph_multivariate(surv_filtered_df, all_FU_CCA_R4_ssgsea_df.loc[info_filtered_df2.index, ['ssGSEA']])
coxph_uni_df
# Out:
# [1] "AIC of cox model:  663.291731727036"
# [1] "Proportional Hazards Assumption: "
#            chisq df         p
# ssGSEA 0.1889458  1 0.6637955
# GLOBAL 0.1889458  1 0.6637955
#   Variable      coef exp(coef)  se(coef)         z  Pr(>|z|) lower .95  \
# 0   ssGSEA  0.482429  1.620005  0.120718  3.996342  0.000064  1.278678
#
#   upper .95  log_lower .95  log_upper .95   q-value
# 0  2.052445       0.245827       0.719032  0.000064

# %%
MyLib.save_csv(coxph_mv_df, 'FU_CCA_cox_mutlivariate_R4_ssGSEA.csv', index=False)
# Out:
# File  Remaining_Analyses/output_figs_patients/FU_CCA_cox_mutlivariate_R4_ssGSEA.csv saved, shape: (28, 11)

# %% [markdown]
# ## TP63 (not in the data)

# %%
'TP63' in exp_df.index
# Out:
# False

# %% [markdown]
# ## Save results

# %%
FU_CCA_R3_ssgsea_df
# Out:
#            ssGSEA High_ssGSEA
# CCA#20  -1.704494        Rest
# CCA#21  -1.001702        Rest
# CCA#22  -1.354439        Rest
# CCA#23  -1.171998        Rest
# CCA#30   0.404393        Rest
# ...           ...         ...
# CCA#198 -0.813921        Rest
# CCA#206 -0.300601        Rest
# CCA#208 -0.912085        Rest
# CCA#210 -1.813355        Rest
# CCA#216 -0.651531        Rest
#
# [94 rows x 2 columns]

# %%
FU_CCA_R4_ssgsea_df
# Out:
#            ssGSEA  High_ssGSEA
# CCA#20   0.190771         Rest
# CCA#21   1.134242  R4 Enriched
# CCA#22  -0.346277         Rest
# CCA#23   1.971387  R4 Enriched
# CCA#30  -0.334695         Rest
# ...           ...          ...
# CCA#198  0.905242  R4 Enriched
# CCA#206  0.262883         Rest
# CCA#208  0.325318         Rest
# CCA#210 -0.089419         Rest
# CCA#216  0.736910  R4 Enriched
#
# [94 rows x 2 columns]

# %%
fu_cca_mut_df
# Out:
#             IDH1_MT IDH2_MT BAP1_MT PBRM1_MT ARID1A_MT KRAS_MT SMAD4_MT  \
# Patient No.
# CCA#101           0       0       0        0         0       0        0
# CCA#102           0       0       0        0         0       0        0
# CCA#103           0       0       0        0         0       1        1
# CCA#105           0       0       0        0         0       0        0
# CCA#110           0       0       0        0         0       0        0
# ...             ...     ...     ...      ...       ...     ...      ...
# CCA#92            0       0       0        0         0       0        1
# CCA#93            0       0       0        0         0       0        0
# CCA#94            0       0       0        0         1       0        0
# CCA#95            0       0       0        0         1       0        0
# CCA#98            0       0       1        0         1       0        0
#
#             FGFR2_MT mutation_R3 mutation_R4
# Patient No.
# CCA#101            0          WT          WT
# CCA#102            0          WT          WT
# CCA#103            0          WT          MT
# CCA#105            0          WT          WT
# CCA#110            0          WT          WT
# ...              ...         ...         ...
# CCA#92             0          WT          MT
# CCA#93             0          WT          WT
# CCA#94             0          WT          WT
# CCA#95             0          WT          WT
# CCA#98             0          MT          WT
#
# [94 rows x 10 columns]

# %%
d1 = FU_CCA_R3_ssgsea_df[['ssGSEA', 'High_ssGSEA']]
d1 = d1.rename(columns={'ssGSEA':'R3_ssGSEA', 'High_ssGSEA':f'R3_status (thr={round(R3_threshold,3)})'})
d2 = FU_CCA_R4_ssgsea_df[['ssGSEA', 'High_ssGSEA']]
d2 = d2.rename(columns={'ssGSEA':'R4_ssGSEA', 'High_ssGSEA':f'R4_status (thr={round(R4_threshold,3)})'})
# df = pd.concat([d1, d2, fu_cca_mut_df, exp_df.T], axis=1)
# MyLib.save_csv(df, 'FU_CCA_ssGSEA_mutations_RNA.csv')
df = pd.concat([d1, d2, fu_cca_mut_df[['mutation_R3', 'mutation_R4']]], axis=1)
MyLib.save_csv(df, 'FU_CCA_ssGSEA_mutations.csv')
# Out:
# File  Remaining_Analyses/output_figs_patients/FU_CCA_ssGSEA_mutations.csv saved, shape: (94, 6)

# %% [markdown]
# # FU_CCA dataset - iCCA classification

# %%
FU_CCA_dataset_file = 'Patients_Data/FU-CCA/Supplementary_Table_1 (Contains RNASEQ).xlsx'
supp = pd.ExcelFile(os.path.join(io_library.input_dir, FU_CCA_dataset_file))

info_df = supp.parse(supp.sheet_names[1])
info_df['Tumor (T) RNA-seq ID'] = info_df['Tumor (T) RNA-seq ID'].apply(lambda x: x.replace('_', '-') if not pd.isna(x) else x)
temp_df = info_df[['Patient No.', 'Tumor (T) RNA-seq ID', 'iCCA classification']].copy()
temp_df['iCCA classification'] = temp_df['iCCA classification'].apply(lambda x:np.nan if x=='Unknown' else x)
temp_df = temp_df.dropna().copy()

ids = dict(zip(temp_df['Tumor (T) RNA-seq ID'], temp_df['Patient No.']))

exp_df = supp.parse(supp.sheet_names[5])
exp_df = exp_df.rename(columns={'RNA-seq ID':'Gene'})
exp_df.set_index('Gene', drop=True, inplace=True)
exp_df = exp_df[temp_df['Tumor (T) RNA-seq ID']]
exp_df = exp_df.rename(columns={col:ids[col] for col in exp_df.columns})
exp_df = exp_df.T.astype(float)
exp_df = exp_df.dropna(axis=1)

# %%
rna_HNF1B = exp_df[['HNF1B']]

# %%
temp_df.set_index('Patient No.', drop=True, inplace=True)
temp_df['iCCA class'] = temp_df['iCCA classification'].apply(lambda x: 1 if x == 'small iBD' else 0)
df = pd.concat([rna_HNF1B, temp_df[['iCCA class', 'iCCA classification']]], axis=1)
df = df.sort_values(by=['HNF1B'], ascending=False)
print(df.shape)
df.head(10)
# Out:
# (72, 3)
#              HNF1B  iCCA class iCCA classification
# CCA#70   83.566572           1           small iBD
# CCA#98   69.732399           1           small iBD
# CCA#90   68.508424           1           small iBD
# CCA#73   59.482620           1           small iBD
# CCA#47   49.054285           1           small iBD
# CCA#121  48.422540           1           small iBD
# CCA#51   48.083103           1           small iBD
# CCA#59   47.314013           1           small iBD
# CCA#72   46.322311           1           small iBD
# CCA#34   45.322151           1           small iBD

# %%
color = {'large iBD': control_color, 'small iBD': '#A00000'}
x = 'iCCA classification'
y = 'HNF1B'
y_label = 'HNF1B mRNA Expression'
title = 'FU-CCA Cohort'
Utils.compare_visualize_cat_features(df, x=x, y=y, color_dic=color, test='ranksum', y_label=y_label,title=title,
                                     ylim_top=100, ytick_step=25, label_newline=True, title_fontsize=8, tick_fontsize=6, label_fontsize=7., figure_width=1.3, figure_height=1.6, save_figure=True, file_suffix='_iBD')
# Out:
# ranksum p-value=0.006118840559718804
# There is a significant association.

# %% [markdown]
# # CPTAC-iCCA dataset - CPTAC

# %% [markdown]
# Dong, Liangqing, et al. "Proteogenomic characterization identifies clinically relevant subgroups of intrahepatic cholangiocarcinoma." Cancer cell 40.1 (2022): 70-87.
# [Link](https://www.sciencedirect.com/science/article/pii/S1535610821006590)

# %%
CPTAC_iCCA_dataset_file = 'Patients_Data/CPTAC-FU_iCCA/1-s2.0-S1535610821006590-mmc2.xlsx'
supp = pd.ExcelFile(os.path.join(io_library.input_dir, CPTAC_iCCA_dataset_file))

info_df = supp.parse(supp.sheet_names[1], skiprows=1, header=0, index_col=0)
info_df = info_df[(info_df['RNA_seq']=='Yes') & (info_df['WES_seq']=='Yes')].copy()
info_df
# Out:
#                Sex  Age Intrahepatic metastasis Liver fluke  \
# Patient_ID
# 111           Male   49                      No          No
# 113           Male   59                     Yes          No
# 115           Male   74                      No          No
# 117         Female   64                      No         Yes
# 121         Female   71                      No          No
# ...            ...  ...                     ...         ...
# 981         Female   65                      No          No
# 983         Female   65                      No          No
# 987           Male   63                     Yes          No
# 993         Female   63                      No          No
# 995         Female   69                      No          No
#
#             HBsAg  (1, positive; 0, negative) Biliary tract stone disease  \
# Patient_ID
# 111                                         1                          No
# 113                                         0                          No
# 115                                         0                          No
# 117                                         0                          No
# 121                                         0                          No
# ...                                       ...                         ...
# 981                                         0                          No
# 983                                         1                          No
# 987                                         0                          No
# 993                                         1                          No
# 995                                         0                          No
#
#             Tumor_size_diameter (cm) Vascular invasion Liver cirrhosis  \
# Patient_ID
# 111                              7.5               Yes              No
# 113                             15.0               Yes              No
# 115                              4.5               Yes              No
# 117                              4.6                No              No
# 121                              5.2                No              No
# ...                              ...               ...             ...
# 981                              7.5               Yes              No
# 983                              3.3                No              No
# 987                              7.0                No              No
# 993                              3.7                No             Yes
# 995                              4.5                No              No
#
#            Regional lymph Node metastasis  ...  \
# Patient_ID                                 ...
# 111                                    No  ...
# 113                                   Yes  ...
# 115                                    No  ...
# 117                                    No  ...
# 121                                    No  ...
# ...                                   ...  ...
# 981                                   Yes  ...
# 983                                    No  ...
# 987                                    No  ...
# 993                                    No  ...
# 995                                    No  ...
#
#            γ-GT, γ-glutamyltransferase (U/L) TNM stage  \
# Patient_ID
# 111                                     80.0      IIIA
# 113                                     40.0      IIIB
# 115                                     29.0      IIIB
# 117                                     27.0      IIIB
# 121                                     23.0        IB
# ...                                      ...       ...
# 981                                     24.0      IIIB
# 983                                     20.0        IA
# 987                                     47.0        II
# 993                                     25.0      IIIB
# 995                                     20.0      IIIB
#
#             OS, overall survival (day)  OS_event  Adjuvant therapies  WES_seq  \
# Patient_ID
# 111                              682.0       1.0                TACE      Yes
# 113                              183.0       1.0        No treatment      Yes
# 115                             1806.0       0.0        No treatment      Yes
# 117                              808.0       1.0        Chemotherapy      Yes
# 121                             1317.0       0.0        No treatment      Yes
# ...                                ...       ...                 ...      ...
# 981                              447.0       0.0        Chemotherapy      Yes
# 983                              330.0       0.0        No treatment      Yes
# 987                              427.0       0.0                TACE      Yes
# 993                              400.0       0.0        No treatment      Yes
# 995                              379.0       0.0        Chemotherapy      Yes
#
#             RNA_seq  Proteome  Phosphoproteome Microbiome
# Patient_ID
# 111             Yes        No               No         No
# 113             Yes        No               No         No
# 115             Yes       Yes              Yes         No
# 117             Yes       Yes              Yes         No
# 121             Yes       Yes              Yes        Yes
# ...             ...       ...              ...        ...
# 981             Yes       Yes              Yes        Yes
# 983             Yes       Yes              Yes         No
# 987             Yes        No               No         No
# 993             Yes       Yes              Yes         No
# 995             Yes       Yes              Yes        Yes
#
# [249 rows x 28 columns]

# %%
exp_df = supp.parse(supp.sheet_names[3], skiprows=1, header=0, index_col=0)
exp_df = exp_df.rename(columns={c:int(c.strip()) for c in exp_df.columns})
exp_df = exp_df.loc[:,info_df.index.tolist()]
exp_df.shape
# Out:
# (20173, 249)

# %%
mutation = ['IDH1', 'IDH2', 'BAP1', 'PBRM1', 'ARID1A', 'KRAS', 'SMAD4', 'BRAF']
CPTAC_iCCA_mut_df = pd.DataFrame(0, index=info_df.index, columns=mutation)
mut_maf_df = supp.parse(supp.sheet_names[2], skiprows=1, header=0)
mut_maf_df = mut_maf_df[mut_maf_df['Gene'].isin(mutation)]

# %%
gp = mut_maf_df.groupby('Gene')
for gene, df in gp:
    ids = df['Sample_ID'].unique()
    shared_ids = list(set(ids).intersection(info_df.index.values))
    CPTAC_iCCA_mut_df.loc[shared_ids, gene] = 1

# %%
fusion_df = supp.parse(supp.sheet_names[8], skiprows=1, header=0, index_col=0)
fusion_df['LeftGene'] = fusion_df['LeftGene'].apply(lambda x: x.strip())
fusion_df['RightGene'] = fusion_df['RightGene'].apply(lambda x: x.strip())
fusion_df = fusion_df[(fusion_df['LeftGene']=='FGFR2') | (fusion_df['RightGene']=='FGFR2')]

CPTAC_iCCA_mut_df['FGFR2'] = 0
CPTAC_iCCA_mut_df.loc[fusion_df.index, 'FGFR2'] = 1

# %%
muts_l =  ['IDH1_MT', 'IDH2_MT', 'BAP1_MT',  'FGFR2_MT']
CPTAC_iCCA_mut_df['mutation_R3'] = (CPTAC_iCCA_mut_df['IDH1'] | CPTAC_iCCA_mut_df['IDH2'] | CPTAC_iCCA_mut_df['BAP1'] | CPTAC_iCCA_mut_df['FGFR2']).astype(int)
CPTAC_iCCA_mut_df['mutation_R3'] = CPTAC_iCCA_mut_df['mutation_R3'].replace({0: 'WT', 1: 'MT'})


R4_muts_l=['KRAS_MT', 'SMAD4_MT', 'BRAF_MT' ]
CPTAC_iCCA_mut_df['mutation_R4'] = (CPTAC_iCCA_mut_df['KRAS'] | CPTAC_iCCA_mut_df['SMAD4'] | CPTAC_iCCA_mut_df['BRAF']).astype(int)
CPTAC_iCCA_mut_df['mutation_R4'] = CPTAC_iCCA_mut_df['mutation_R4'].replace({0: 'WT', 1: 'MT'})

CPTAC_iCCA_mut_df = CPTAC_iCCA_mut_df.rename(columns={c:c+'_MT' for c in ['IDH1', 'IDH2', 'BAP1',  'FGFR2', 'ARID1A', 'PBRM1','KRAS', 'SMAD4', 'BRAF']})
CPTAC_iCCA_mut_df.head(10)
# Out:
#             IDH1_MT  IDH2_MT  BAP1_MT  PBRM1_MT  ARID1A_MT  KRAS_MT  SMAD4_MT  \
# Patient_ID
# 111               0        0        0         0          0        0         0
# 113               0        0        0         0          0        0         0
# 115               0        0        0         0          0        0         0
# 117               1        0        0         0          0        0         0
# 121               0        0        0         0          1        0         0
# 123               1        0        0         0          0        0         0
# 125               0        0        1         0          0        1         0
# 127               0        0        0         0          0        0         0
# 131               0        0        0         0          0        1         0
# 133               0        0        0         0          0        0         0
#
#             BRAF_MT  FGFR2_MT mutation_R3 mutation_R4
# Patient_ID
# 111               0         0          WT          WT
# 113               0         1          MT          WT
# 115               0         0          WT          WT
# 117               0         0          MT          WT
# 121               0         0          WT          WT
# 123               0         0          MT          WT
# 125               0         0          MT          MT
# 127               0         0          WT          WT
# 131               0         0          WT          MT
# 133               0         0          WT          WT

# %% [markdown]
# ## ssGSEA for R3 Signature

# %%
R3_features_filtered = sorted(set(R3_features).intersection(set(exp_df.index)))
print('Shared features:', len(R3_features_filtered))
# Out:
# Shared features: 48

# %%
ssgsea_df = MyRFunctions.ssgsea(exp_df, R3_features_filtered)
# Out:
# [1] "Calculating ranks..."
# [1] "Calculating absolute values from ranks..."
# [1] "Normalizing..."

# %%
CPTAC_iCCA_R3_ssgsea_df = zscore(ssgsea_df)
CPTAC_iCCA_R3_ssgsea_df.head(10)
# Out:
#        ssGSEA
# 111 -1.319180
# 113  0.039561
# 115 -0.630997
# 117  0.603531
# 121  0.848034
# 123  0.486694
# 125 -1.643681
# 127 -2.552286
# 131 -2.200880
# 133 -1.757480

# %%
MyVisualization.plot_distribution(CPTAC_iCCA_R3_ssgsea_df['ssGSEA'])

# %%
R3_threshold = np.percentile(CPTAC_iCCA_R3_ssgsea_df['ssGSEA'], 75)
print('Enrichment cut-off:', R3_threshold) 
CPTAC_iCCA_R3_ssgsea_df['High_ssGSEA'] = (CPTAC_iCCA_R3_ssgsea_df['ssGSEA'] > R3_threshold).astype(int)
CPTAC_iCCA_R3_ssgsea_df['High_ssGSEA'] = CPTAC_iCCA_R3_ssgsea_df['High_ssGSEA'].replace({0: 'Rest', 1: 'R3 Enriched'})
CPTAC_iCCA_R3_ssgsea_df.head(10)
# Out:
# Enrichment cut-off: 0.7982507604469877
#        ssGSEA  High_ssGSEA
# 111 -1.319180         Rest
# 113  0.039561         Rest
# 115 -0.630997         Rest
# 117  0.603531         Rest
# 121  0.848034  R3 Enriched
# 123  0.486694         Rest
# 125 -1.643681         Rest
# 127 -2.552286         Rest
# 131 -2.200880         Rest
# 133 -1.757480         Rest

# %%
df = pd.concat([CPTAC_iCCA_R3_ssgsea_df, CPTAC_iCCA_mut_df, exp_df.T], axis=1)
# MyLib.save_csv(df, 'CPTAC_iCCA_R3_ssGSEA_mutations_RNA.csv')
df = df.sort_values(by=['ssGSEA'], ascending=False)

# %% [markdown]
# ## R3 Mutation Signature comparison

# %%
color = {'WT': control_color, 'MT': R3_color}
x = 'mutation_R3'
y = 'ssGSEA'
y_label = 'ssGSEA Score'
x_label = 'CPTAC-iCCA Cohort'
title = f'R3 Signature (n={len(R3_features_filtered)})'
print('Mutations:', muts_l)
Utils.compare_visualize_cat_features(df, x=x, y=y, color_dic=color, y_label=y_label, x_label=x_label, title=title, label_newline=False,title_fontsize=7, tick_fontsize=6, label_fontsize=7.5, ylim_top=3., ytick_step=1.5, figure_width=1.4, figure_height=1.5, test='ranksum', save_figure=True)
# Out:
# Mutations: ['IDH1_MT', 'IDH2_MT', 'BAP1_MT', 'FGFR2_MT']
# ranksum p-value=1.9393142909117975e-16
# There is a significant association.

# %%
title = 'CPTAC-iCCA Cohort'
Utils.split_mutation_profiles(df, R3_muts_l=muts_l, R4_muts_l=R4_muts_l, color_dic=color_dic, title=title, file_name='CPTAC_iCCA_R3')
# Out:
# Mutation_Signature  R3  R3 & R4  R4   WT
# High_ssGSEA
# R3 Enriched         40        4   1   17
# Rest                44        3  39  101
# -------------------
# High_ssGSEA         R3 Enriched  Rest
# Mutation_Signature
# R4                            5    42
# WT                           57   145
# Odds Ratio: 0.3028404344193818
# P-value: 0.013979603603211077
# There is a significant association between R4 and WT
# ===============================
# {('R4', 'WT'): 0.013979603603211077}
# -------------------
# High_ssGSEA         R3 Enriched  Rest
# Mutation_Signature
# R3                           44    47
# WT                           18   140
# Odds Ratio: 7.281323877068558
# P-value: 2.340677223380552e-10
# There is a significant association between R3 and WT
# ===============================
# {('R3', 'WT'): 2.340677223380552e-10}
# -------------------
# p-value= [2.340677223380552e-10, 0.013979603603211077]

# %% [markdown]
# ## HNF1B - RNA

# %%
color = {'Rest': control_color, 'R3 Enriched': R3_color}
x = 'High_ssGSEA'
y = 'HNF1B'
y_label = 'HNF1B mRNA Expression'
title = 'CPTAC-iCCA Cohort'
# title = f'Bipotential R3 Signature (n={len(R3_features_filtered)})'x_label=x_label,
Utils.compare_visualize_cat_features(df, x=x, y=y, color_dic=color, test='ranksum',  y_label=y_label, title=title, label_newline=True, title_fontsize=8,title_height=1.0, ylim_top=10, ytick_step=2.5, tick_fontsize=7, label_fontsize=7.,figure_width=1.3, figure_height=1.5, save_figure=True)
# Out:
# ranksum p-value=2.2454927989959007e-19
# There is a significant association.

# %% [markdown]
# ## SULT1A1 - RNA

# %%
color = {'Rest': control_color, 'R3 Enriched': R3_color}
x = 'High_ssGSEA'
y = 'SULT1A1'
y_label = 'SULT1A1 mRNA Expression'
title = 'CPTAC-iCCA Cohort'
Utils.compare_visualize_cat_features(df, x=x, y=y, color_dic=color, test='ranksum', y_label=y_label, title=title, label_newline=True, title_fontsize=8, ylim_top=10, ytick_step=2.5, title_height=1.0, tick_fontsize=6, label_fontsize=7.,figure_width=1.2, figure_height=1.5, save_figure=True)
# Out:
# ranksum p-value=1.1172478791494769e-07
# There is a significant association.

# %% [markdown]
# ## R3 Survival Analysis

# %%
cluster = 'R3'
CPTAC_iCCA_R3_ssgsea_df['R3_ssGSEA'] = CPTAC_iCCA_R3_ssgsea_df['High_ssGSEA'].replace({'R3 Enriched':1, 'Rest': 0})
surv_df = info_df[['OS, overall survival (day)', 'OS_event']].dropna(axis=0, how='all').astype(float)
surv_df['Group'] = 0#'Low ssGSEA'
surv_df.loc[CPTAC_iCCA_R3_ssgsea_df.loc[surv_df.index, 'R3_ssGSEA'] ==1, 'Group'] = 1#'High ssGSEA'
surv_df
# Out:
#             OS, overall survival (day)  OS_event  Group
# Patient_ID
# 111                              682.0       1.0      0
# 113                              183.0       1.0      0
# 115                             1806.0       0.0      0
# 117                              808.0       1.0      0
# 121                             1317.0       0.0      1
# ...                                ...       ...    ...
# 981                              447.0       0.0      0
# 983                              330.0       0.0      0
# 987                              427.0       0.0      0
# 993                              400.0       0.0      1
# 995                              379.0       0.0      0
#
# [238 rows x 3 columns]

# %%
colors_l = ['#a00000','#077f97']
labels = ['Low', ' High']
MyRFunctions.survival_analysis(surv_df[['OS, overall survival (day)', 'OS_event']], surv_df[['Group']], 'Group', f'CPTAC-iCCA Cohort Overal Survival ({cluster} signature ssGSEA score)', legend_lbls=labels, colors_elms=colors_l, plot_path=os.path.join(io_library.output_dir, f'CPTAC_iCCA_Overal_Survival_Plot_{cluster}.pdf'))
# Out:
# 0 178
# 1 60
# ------

# %% [markdown]
# ### Cox Regression

# %%
info_filtered_df = info_df.loc[surv_df.index]
info_filtered_df.shape
# Out:
# (238, 28)

# %%
info_filtered_df = info_filtered_df.rename(columns={'HBsAg  (1, positive; 0, negative)':'HBsAg', 'Tumor_size_diameter (cm)':'Tumor_size_diameter', 'TB: total bilirubin (μmol/L)':'TB total bilirubin', 'CA19-9, carbohydrate antigen 19-9 (U/mL)':'CA19-9', 'CEA, carcinoembryonic antigen (μg/L)':'CEA carcinoembryonic antigen'})

# %%
cat_feats_cols = ['Sex', 'Intrahepatic metastasis', 'Liver fluke', 'Biliary tract stone disease', 'Vascular invasion', 'Liver cirrhosis','Regional lymph Node metastasis','Perineural invasion', 'TNM stage','Adjuvant therapies']#'Distal metastasis',  
cont_feats_cols = ['HBsAg', 'Age', 'Tumor_size_diameter', 'TB total bilirubin', 'CA19-9', 'CEA carcinoembryonic antigen']

# %%
cat_clinical_feats_df = Utils.create_onehot_encoding_columns(info_filtered_df, cat_feats_cols)
# Out:
# Sex
# Reference level: Sex_Female
# ------
# Intrahepatic metastasis
# Reference level: Intrahepatic metastasis_No
# ------
# Liver fluke
# Reference level: Liver fluke_No
# ------
# Biliary tract stone disease
# Reference level: Biliary tract stone disease_No
# ------
# Vascular invasion
# Reference level: Vascular invasion_No
# ------
# Liver cirrhosis
# Reference level: Liver cirrhosis_No
# ------
# Regional lymph Node metastasis
# Reference level: Regional lymph Node metastasis_No
# ------
# Perineural invasion
# Reference level: Perineural invasion_No
# ------
# TNM stage
# Reference level: TNM stage_IA
# ------
# Adjuvant therapies
# Reference level: Adjuvant therapies_Chemotherapy
# ------

# %%
# all_clinical_feats_df = pd.concat([CPTAC_iCCA_R3_ssgsea_df.loc[info_filtered_df.index, ['ssGSEA']], info_filtered_df[cont_feats_cols], info_filtered_df[cat_feats_cols]], axis=1)
all_clinical_feats_df = pd.concat([CPTAC_iCCA_R3_ssgsea_df.loc[info_filtered_df.index, ['ssGSEA']], info_filtered_df[cont_feats_cols], cat_clinical_feats_df], axis=1)
all_clinical_feats_df = all_clinical_feats_df.rename(columns={'ssGSEA': 'R3_ssGSEA'})
all_clinical_feats_df = all_clinical_feats_df.rename(columns={col: col.replace('-', '_') for col in all_clinical_feats_df.columns})# R cannot take -
all_clinical_feats_df = all_clinical_feats_df.rename(columns={col: col.replace(' ', '_') for col in all_clinical_feats_df.columns})# R cannot take space
# all_clinical_feats_df = all_clinical_feats_df.astype(float)
all_clinical_feats_df.shape
# Out:
# (238, 22)

# %%
MyRFunctions.find_collinearity(all_clinical_feats_df.drop(['HBsAg'], axis=1), all_clinical_feats_df[['HBsAg']])
# Out:
# Model :
# HBsAg ~ R3_ssGSEA + Age + Tumor_size_diameter + TB_total_bilirubin +
#     CA19_9 + CEA_carcinoembryonic_antigen + Sex_Male + Intrahepatic_metastasis_Yes +
#     Liver_fluke_Yes + Biliary_tract_stone_disease_Yes + Vascular_invasion_Yes +
#     Liver_cirrhosis_Yes + Regional_lymph_Node_metastasis_Yes +
#     Perineural_invasion_Yes + TNM_stage_IB + TNM_stage_II + TNM_stage_IIIA +
#     TNM_stage_IIIB + TNM_stage_IV + Adjuvant_therapies_No_treatment +
#     Adjuvant_therapies_TACE

# %%
# MyLib.save_csv(surv_df[['OS, overall survival (day)', 'OS_event']], 'survival.csv')
# MyLib.save_csv(all_clinical_feats_df, 'all_clinical_feats_df.csv')

# %%
coxph_mv_df = MyRFunctions.coxph_multivariate(surv_df[['OS, overall survival (day)', 'OS_event']], all_clinical_feats_df)
coxph_mv_df
# Out:
# [1] "AIC of cox model:  876.765855334238"
# [1] "Proportional Hazards Assumption: "
#                                           chisq df          p
# R3_ssGSEA                          4.073358e-01  1 0.52332487
# HBsAg                              1.498695e-01  1 0.69866013
# Age                                2.768905e+00  1 0.09611189
# Tumor_size_diameter                3.583227e+00  1 0.05836568
# TB_total_bilirubin                 3.028917e-04  1 0.98611449
# CA19_9                             5.121035e-02  1 0.82097040
# CEA_carcinoembryonic_antigen       2.326403e-02  1 0.87877247
# Sex_Male                           1.152171e-02  1 0.91451986
# Intrahepatic_metastasis_Yes        1.082871e+00  1 0.29805623
# Liver_fluke_Yes                    1.995188e+00  1 0.15779946
# Biliary_tract_stone_disease_Yes    2.615538e+00  1 0.10582163
# Vascular_invasion_Yes              2.328279e-01  1 0.62943487
# Liver_cirrhosis_Yes                6.685061e-01  1 0.41357293
# Regional_lymph_Node_metastasis_Yes 2.664267e+00  1 0.10262507
# Perineural_invasion_Yes            8.765107e-01  1 0.34915915
# TNM_stage_IB                       2.645977e-02  1 0.87078253
# TNM_stage_II                       5.897350e-02  1 0.80812579
# TNM_stage_IIIA                     5.749859e+00  1 0.01648998
# TNM_stage_IIIB                     1.999037e+00  1 0.15739914
# TNM_stage_IV                       4.509470e-01  1 0.50188561
# Adjuvant_therapies_No_treatment    5.447946e+00  1 0.01959135
# Adjuvant_therapies_TACE            1.577586e-01  1 0.69122855
# GLOBAL                             3.612661e+01 22 0.02943082
#                               Variable      coef exp(coef)  se(coef)  \
# 0   Regional_lymph_Node_metastasis_Yes  1.288535  3.627467  0.399959
# 1                            R3_ssGSEA -0.339289  0.712277  0.115768
# 2                       TNM_stage_IIIA  1.874748  6.519177  0.672525
# 3                      Liver_fluke_Yes  0.906867  2.476552  0.454863
# 4      Biliary_tract_stone_disease_Yes  1.059183  2.884015  0.513978
# 5                         TNM_stage_IV  1.150495  3.159757  0.644713
# 6          Intrahepatic_metastasis_Yes  0.479899  1.615911  0.266204
# 7                   TB_total_bilirubin  0.007469  1.007497   0.00413
# 8                               CA19_9  0.000086  1.000086  0.000051
# 9                         TNM_stage_II  0.677307   1.96857  0.509826
# 10                                 Age   0.01488  1.014992  0.012292
# 11                      TNM_stage_IIIB  0.501294  1.650855  0.572684
# 12               Vascular_invasion_Yes  0.201281  1.222968  0.286221
# 13                 Tumor_size_diameter  0.037571  1.038285   0.04713
# 14                            Sex_Male -0.161016  0.851279  0.223868
# 15                        TNM_stage_IB  -0.35199  0.703287  0.711928
# 16             Perineural_invasion_Yes  0.090776  1.095024  0.309666
# 17        CEA_carcinoembryonic_antigen  0.000986  1.000986  0.003376
# 18                               HBsAg -0.039145  0.961611  0.321581
# 19     Adjuvant_therapies_No_treatment  0.040763  1.041605   0.27805
# 20             Adjuvant_therapies_TACE -0.045586  0.955438  0.426258
# 21                 Liver_cirrhosis_Yes  0.019696  1.019891  0.400065
#
#            z  Pr(>|z|) lower .95  upper .95  log_lower .95  log_upper .95  \
# 0   3.221664  0.001274  1.656371   7.944186       0.504629       2.072440
# 1  -2.930767  0.003381  0.567684   0.893698      -0.566190      -0.112388
# 2   2.787626   0.00531  1.744771  24.358305       0.556623       3.192873
# 3   1.993716  0.046183  1.015471   6.039864       0.015353       1.798381
# 4   2.060755  0.039326   1.05317   7.897626       0.051804       2.066562
# 5   1.784509  0.074341  0.893045  11.179801      -0.113118       2.414109
# 6   1.802751  0.071427  0.959013   2.722766      -0.041851       1.001648
# 7   1.808513  0.070527  0.999375   1.015686      -0.000626       0.015564
# 8   1.686271  0.091744  0.999986   1.000185      -0.000014       0.000185
# 9   1.328507  0.184011  0.724747   5.347062      -0.321933       1.676547
# 10  1.210553  0.226067   0.99083   1.039742      -0.009212       0.038973
# 11   0.87534  0.381389  0.537328   5.071996      -0.621147       1.623734
# 12  0.703235  0.481909  0.697884    2.14312      -0.359702       0.762263
# 13   0.79718  0.425347  0.946673   1.138764      -0.054802       0.129943
# 14 -0.719243  0.471991  0.548927   1.320167      -0.599789       0.277758
# 15 -0.494418  0.621011  0.174236    2.83875      -1.747344       1.043364
# 16  0.293142  0.769413  0.596809   2.009146      -0.516158       0.697710
# 17  0.291904   0.77036  0.994384   1.007632      -0.005632       0.007603
# 18 -0.121728  0.903114  0.511999   1.806049      -0.669432       0.591141
# 19  0.146604  0.883445  0.603986   1.796304      -0.504205       0.585731
# 20 -0.106944  0.914833  0.414353   2.203098      -0.881036       0.789864
# 21  0.049232  0.960734  0.465605   2.234036      -0.764418       0.803810
#
#      q-value
# 0   0.028039
# 1   0.037194
# 2   0.038937
# 3   0.203205
# 4   0.203205
# 5   0.204438
# 6   0.204438
# 7   0.204438
# 8   0.224262
# 9   0.404823
# 10  0.452134
# 11  0.699213
# 12    0.7068
# 13    0.7068
# 14    0.7068
# 15   0.85389
# 16  0.941551
# 17  0.941551
# 18  0.958397
# 19  0.958397
# 20  0.958397
# 21  0.960734

# %%
MyVisualization.forest_plot(coxph_mv_df, title='CPTAC-iCCA Cohort Multivariate Cox Regression', figure_width=5, figure_height=6, tick_fontsize=8)

# %% [markdown]
# Univariate

# %%
coxph_uni_df = MyRFunctions.coxph_multivariate(surv_df[['OS, overall survival (day)', 'OS_event']], CPTAC_iCCA_R3_ssgsea_df.loc[info_filtered_df.index, ['R3_ssGSEA']])
coxph_uni_df
# Out:
# [1] "AIC of cox model:  934.148682956092"
# [1] "Proportional Hazards Assumption: "
#              chisq df         p
# R3_ssGSEA 1.538044  1 0.2149092
# GLOBAL    1.538044  1 0.2149092
#     Variable      coef exp(coef) se(coef)         z  Pr(>|z|) lower .95  \
# 0  R3_ssGSEA -0.826192  0.437713  0.28191 -2.930693  0.003382  0.251899
#
#   upper .95  log_lower .95  log_upper .95   q-value
# 0  0.760592      -1.378726      -0.273658  0.003382

# %%
MyLib.save_csv(coxph_mv_df, 'CPTAC_iCCA_cox_mutlivariate_R3_ssGSEA.csv', index=False)
# Out:
# File  Remaining_Analyses/output_figs_patients/CPTAC_iCCA_cox_mutlivariate_R3_ssGSEA.csv saved, shape: (22, 11)

# %% [markdown]
# ## ssGSEA for R4 Signature

# %%
cluster = 'R4'
R4_features_filtered = sorted(set(R4_features).intersection(set(exp_df.index)))
print('Shared features:', len(R4_features_filtered))
# Out:
# Shared features: 46

# %%
ssgsea_df = MyRFunctions.ssgsea(exp_df, R4_features_filtered)
# Out:
# [1] "Calculating ranks..."
# [1] "Calculating absolute values from ranks..."
# [1] "Normalizing..."

# %%
CPTAC_iCCA_R4_ssgsea_df = zscore(ssgsea_df)
CPTAC_iCCA_R4_ssgsea_df.head(10)
# Out:
#        ssGSEA
# 111 -1.516126
# 113  0.796358
# 115  0.265844
# 117 -1.586506
# 121  0.370129
# 123 -0.315653
# 125 -0.681380
# 127 -0.263970
# 131  0.227362
# 133 -1.456587

# %%
MyVisualization.plot_distribution(CPTAC_iCCA_R4_ssgsea_df['ssGSEA'])

# %%
R4_threshold = np.percentile(CPTAC_iCCA_R4_ssgsea_df['ssGSEA'], 75)
print('Enrichment cut-off:', R4_threshold) 
CPTAC_iCCA_R4_ssgsea_df['High_ssGSEA'] = (CPTAC_iCCA_R4_ssgsea_df['ssGSEA'] > R4_threshold).astype(int)
CPTAC_iCCA_R4_ssgsea_df['High_ssGSEA'] = CPTAC_iCCA_R4_ssgsea_df['High_ssGSEA'].replace({0: 'Rest', 1: 'R4 Enriched'})
CPTAC_iCCA_R4_ssgsea_df.head(10)
# Out:
# Enrichment cut-off: 0.6252288902391249
#        ssGSEA  High_ssGSEA
# 111 -1.516126         Rest
# 113  0.796358  R4 Enriched
# 115  0.265844         Rest
# 117 -1.586506         Rest
# 121  0.370129         Rest
# 123 -0.315653         Rest
# 125 -0.681380         Rest
# 127 -0.263970         Rest
# 131  0.227362         Rest
# 133 -1.456587         Rest

# %%
df_R4 = pd.concat([CPTAC_iCCA_R4_ssgsea_df, CPTAC_iCCA_mut_df, exp_df.T], axis=1)
# MyLib.save_csv(df, 'FU_CCA_R3_ssGSEA_mutations_RNA.csv')
df_R4 = df_R4.sort_values(by=['ssGSEA'], ascending=False)

# %% [markdown]
# ## R4 Mutation Signature comparison

# %%
color = {'WT': control_color, 'MT': R4_color}
x = 'mutation_R4'
y = 'ssGSEA'
y_label = 'ssGSEA Score'
x_label = 'CPTAC-iCCA Cohort'
title = f'R4 Signature (n={len(R4_features_filtered)})'
print('Mutations:', R4_muts_l)
Utils.compare_visualize_cat_features(df_R4, x=x, y=y, color_dic=color, y_label=y_label, x_label=x_label, title=title,
                                     label_newline=False, title_fontsize=7, tick_fontsize=6, label_fontsize=7.5,
                                     ylim_top=3., ylim_bottom=-3, ytick_step=1.5, figure_width=1.4, figure_height=1.5,
                                     test='ranksum', save_figure=True)
# Out:
# Mutations: ['KRAS_MT', 'SMAD4_MT', 'BRAF_MT']
# ranksum p-value=2.1136295974848662e-13
# There is a significant association.

# %%
title = 'CPTAC-iCCA Cohort'
Utils.split_mutation_profiles(df_R4, R3_muts_l=muts_l, R4_muts_l=R4_muts_l, color_dic=color_dic, title=title, file_name='CPTAC_iCCA_R4')
# Out:
# Mutation_Signature  R3  R3 & R4  R4  WT
# High_ssGSEA
# R4 Enriched          4        2  30  26
# Rest                80        5  10  92
# -------------------
# High_ssGSEA         R4 Enriched  Rest
# Mutation_Signature
# R4                           32    15
# WT                           30   172
# Odds Ratio: 12.231111111111112
# P-value: 1.6087560040043135e-12
# There is a significant association between R4 and WT
# ===============================
# {('R4', 'WT'): 1.6087560040043135e-12}
# -------------------
# High_ssGSEA         R4 Enriched  Rest
# Mutation_Signature
# R3                            6    85
# WT                           56   102
# Odds Ratio: 0.12857142857142856
# P-value: 1.1258430825509619e-07
# There is a significant association between R3 and WT
# ===============================
# {('R3', 'WT'): 1.1258430825509619e-07}
# -------------------
# p-value= [1.1258430825509619e-07, 1.6087560040043135e-12]

# %% [markdown]
# ## R4 Survival Analysis

# %%
CPTAC_iCCA_R4_ssgsea_df['R4_ssGSEA'] = CPTAC_iCCA_R4_ssgsea_df['High_ssGSEA'].replace({'R4 Enriched':1, 'Rest': 0})
surv_df = info_df[['OS, overall survival (day)', 'OS_event']].dropna(axis=0, how='all').astype(float)
surv_df['Group'] = 0#'Low ssGSEA'
surv_df.loc[CPTAC_iCCA_R4_ssgsea_df.loc[surv_df.index, 'R4_ssGSEA'] ==1, 'Group'] = 1#'High ssGSEA'
surv_df
# Out:
#             OS, overall survival (day)  OS_event  Group
# Patient_ID
# 111                              682.0       1.0      0
# 113                              183.0       1.0      1
# 115                             1806.0       0.0      0
# 117                              808.0       1.0      0
# 121                             1317.0       0.0      0
# ...                                ...       ...    ...
# 981                              447.0       0.0      0
# 983                              330.0       0.0      0
# 987                              427.0       0.0      0
# 993                              400.0       0.0      0
# 995                              379.0       0.0      0
#
# [238 rows x 3 columns]

# %%
colors_l = ['#a00000','#077f97']
labels = ['Low', ' High']
MyRFunctions.survival_analysis(surv_df[['OS, overall survival (day)', 'OS_event']], surv_df[['Group']], 'Group', f'CPTAC-iCCA Cohort Overal Survival ({cluster} signature ssGSEA score)', legend_lbls=labels, colors_elms=colors_l, plot_path=os.path.join(io_library.output_dir, f'CPTAC_iCCA_Overal_Survival_Plot_{cluster}.pdf'))
# Out:
# 0 182
# 1 56
# ------

# %% [markdown]
# #### Cox Regression

# %%
all_clinical_feats_df = pd.concat([CPTAC_iCCA_R4_ssgsea_df.loc[info_filtered_df.index, ['ssGSEA']], info_filtered_df[cont_feats_cols], cat_clinical_feats_df], axis=1)
all_clinical_feats_df = all_clinical_feats_df.rename(columns={'ssGSEA': 'R4_ssGSEA'})
all_clinical_feats_df = all_clinical_feats_df.rename(columns={col: col.replace('-', '_') for col in all_clinical_feats_df.columns})# R cannot take -
all_clinical_feats_df = all_clinical_feats_df.rename(columns={col: col.replace(' ', '_') for col in all_clinical_feats_df.columns})# R cannot take space
all_clinical_feats_df = all_clinical_feats_df.astype(float)
all_clinical_feats_df.shape
# Out:
# (238, 22)

# %%
all_clinical_feats_df
# Out:
#             R4_ssGSEA  HBsAg   Age  Tumor_size_diameter  TB_total_bilirubin  \
# Patient_ID
# 111         -1.516126    1.0  49.0                  7.5                 8.4
# 113          0.796358    0.0  59.0                 15.0                 9.2
# 115          0.265844    0.0  74.0                  4.5                 7.9
# 117         -1.586506    0.0  64.0                  4.6                14.1
# 121          0.370129    0.0  71.0                  5.2                 8.6
# ...               ...    ...   ...                  ...                 ...
# 981         -0.437273    0.0  65.0                  7.5                16.2
# 983          0.199961    1.0  65.0                  3.3                14.6
# 987         -1.213917    0.0  63.0                  7.0                 9.3
# 993          0.206530    1.0  63.0                  3.7                23.0
# 995         -0.160339    0.0  69.0                  4.5                11.6
#
#             CA19_9  CEA_carcinoembryonic_antigen  Sex_Male  \
# Patient_ID
# 111           25.2                           2.5       1.0
# 113           35.0                           2.8       1.0
# 115            8.2                           2.0       1.0
# 117            7.9                           1.0       0.0
# 121           24.9                           1.4       0.0
# ...            ...                           ...       ...
# 981            0.8                           2.6       0.0
# 983           28.3                           2.2       0.0
# 987          249.0                           3.6       1.0
# 993          406.3                           1.4       0.0
# 995           28.6                           2.4       0.0
#
#             Intrahepatic_metastasis_Yes  Liver_fluke_Yes  ...  \
# Patient_ID                                                ...
# 111                                 0.0              0.0  ...
# 113                                 1.0              0.0  ...
# 115                                 0.0              0.0  ...
# 117                                 0.0              1.0  ...
# 121                                 0.0              0.0  ...
# ...                                 ...              ...  ...
# 981                                 0.0              0.0  ...
# 983                                 0.0              0.0  ...
# 987                                 1.0              0.0  ...
# 993                                 0.0              0.0  ...
# 995                                 0.0              0.0  ...
#
#             Liver_cirrhosis_Yes  Regional_lymph_Node_metastasis_Yes  \
# Patient_ID
# 111                         0.0                                 0.0
# 113                         0.0                                 1.0
# 115                         0.0                                 0.0
# 117                         0.0                                 0.0
# 121                         0.0                                 0.0
# ...                         ...                                 ...
# 981                         0.0                                 1.0
# 983                         0.0                                 0.0
# 987                         0.0                                 0.0
# 993                         1.0                                 0.0
# 995                         0.0                                 0.0
#
#             Perineural_invasion_Yes  TNM_stage_IB  TNM_stage_II  \
# Patient_ID
# 111                             0.0           0.0           0.0
# 113                             0.0           0.0           0.0
# 115                             0.0           0.0           0.0
# 117                             1.0           0.0           0.0
# 121                             0.0           1.0           0.0
# ...                             ...           ...           ...
# 981                             0.0           0.0           0.0
# 983                             0.0           0.0           0.0
# 987                             0.0           0.0           1.0
# 993                             0.0           0.0           0.0
# 995                             0.0           0.0           0.0
#
#             TNM_stage_IIIA  TNM_stage_IIIB  TNM_stage_IV  \
# Patient_ID
# 111                    1.0             0.0           0.0
# 113                    0.0             1.0           0.0
# 115                    0.0             1.0           0.0
# 117                    0.0             1.0           0.0
# 121                    0.0             0.0           0.0
# ...                    ...             ...           ...
# 981                    0.0             1.0           0.0
# 983                    0.0             0.0           0.0
# 987                    0.0             0.0           0.0
# 993                    0.0             1.0           0.0
# 995                    0.0             1.0           0.0
#
#             Adjuvant_therapies_No_treatment  Adjuvant_therapies_TACE
# Patient_ID
# 111                                     0.0                      1.0
# 113                                     1.0                      0.0
# 115                                     1.0                      0.0
# 117                                     0.0                      0.0
# 121                                     1.0                      0.0
# ...                                     ...                      ...
# 981                                     0.0                      0.0
# 983                                     1.0                      0.0
# 987                                     0.0                      1.0
# 993                                     1.0                      0.0
# 995                                     0.0                      0.0
#
# [238 rows x 22 columns]

# %%
coxph_mv_df = MyRFunctions.coxph_multivariate(surv_df, all_clinical_feats_df)
coxph_mv_df
# Out:
# [1] "AIC of cox model:  883.900730976694"
# [1] "Proportional Hazards Assumption: "
#                                           chisq df           p
# R4_ssGSEA                          2.124368e+00  1 0.144972546
# HBsAg                              1.497883e-01  1 0.698737718
# Age                                2.384108e+00  1 0.122574865
# Tumor_size_diameter                3.299235e+00  1 0.069312145
# TB_total_bilirubin                 5.555600e-02  1 0.813662977
# CA19_9                             1.247996e-02  1 0.911050369
# CEA_carcinoembryonic_antigen       4.502564e-02  1 0.831956890
# Sex_Male                           4.996577e-04  1 0.982166353
# Intrahepatic_metastasis_Yes        7.505341e-01  1 0.386307184
# Liver_fluke_Yes                    1.893091e+00  1 0.168853668
# Biliary_tract_stone_disease_Yes    3.315794e+00  1 0.068617161
# Vascular_invasion_Yes              1.891851e-01  1 0.663595682
# Liver_cirrhosis_Yes                8.777044e-01  1 0.348831189
# Regional_lymph_Node_metastasis_Yes 3.331419e+00  1 0.067968192
# Perineural_invasion_Yes            9.783984e-01  1 0.322594540
# TNM_stage_IB                       3.402936e-02  1 0.853644369
# TNM_stage_II                       8.991274e-02  1 0.764288119
# TNM_stage_IIIA                     7.231541e+00  1 0.007163371
# TNM_stage_IIIB                     2.420594e+00  1 0.119749553
# TNM_stage_IV                       2.896201e-01  1 0.590464101
# Adjuvant_therapies_No_treatment    7.083059e+00  1 0.007781605
# Adjuvant_therapies_TACE            1.837536e-01  1 0.668167078
# GLOBAL                             3.650997e+01 22 0.026754990
#                               Variable      coef  exp(coef)  se(coef)  \
# 0                       TNM_stage_IIIA  2.431573  11.376766   0.64595
# 1   Regional_lymph_Node_metastasis_Yes  1.382637   3.985398  0.399024
# 2                         TNM_stage_IV  1.505594   4.506831  0.641127
# 3      Biliary_tract_stone_disease_Yes  1.089648   2.973226  0.514782
# 4                         TNM_stage_II  0.946574   2.576866  0.506052
# 5                   TB_total_bilirubin  0.007082   1.007107  0.004322
# 6                      Liver_fluke_Yes  0.752883   2.123111  0.461858
# 7          Intrahepatic_metastasis_Yes  0.409653   1.506295  0.262191
# 8                                  Age  0.017709   1.017867  0.012283
# 9                               CA19_9  0.000076   1.000076  0.000053
# 10                      TNM_stage_IIIB  0.568515   1.765644  0.580796
# 11                           R4_ssGSEA  0.126754   1.135138  0.140145
# 12                 Tumor_size_diameter  0.040961   1.041811  0.048119
# 13        CEA_carcinoembryonic_antigen  0.002581   1.002584  0.003544
# 14                 Liver_cirrhosis_Yes  0.179094   1.196133  0.400727
# 15                        TNM_stage_IB -0.308016   0.734903  0.716267
# 16                            Sex_Male -0.142403   0.867272  0.226525
# 17               Vascular_invasion_Yes  0.137159    1.14701  0.286335
# 18             Adjuvant_therapies_TACE -0.234997   0.790573   0.41899
# 19             Perineural_invasion_Yes  0.079016   1.082221   0.31735
# 20                               HBsAg  0.083683   1.087285  0.316945
# 21     Adjuvant_therapies_No_treatment  -0.04492   0.956074  0.282927
#
#            z  Pr(>|z|) lower .95  upper .95  log_lower .95  log_upper .95  \
# 0   3.764338  0.000167  3.207638  40.350814       1.165535       3.697612
# 1   3.465046   0.00053  1.823147   8.712076       0.600564       2.164710
# 2   2.348357  0.018856  1.282754  15.834311       0.249009       2.762179
# 3   2.116718  0.034284  1.084039   8.154754       0.080694       2.098601
# 4   1.870506  0.061414  0.955739   6.947754      -0.045270       1.938418
# 5   1.638585    0.1013  0.998612   1.015674      -0.001389       0.015553
# 6   1.630116  0.103077  0.858694   5.249371      -0.152343       1.658108
# 7   1.562424  0.118188  0.901017   2.518183      -0.104231       0.923538
# 8   1.441773  0.149366  0.993655   1.042668      -0.006365       0.041783
# 9   1.424616  0.154268  0.999971   1.000181      -0.000029       0.000181
# 10  0.978855  0.327652  0.565625   5.511599      -0.569824       1.706855
# 11   0.90445  0.365757  0.862496   1.493963      -0.147925       0.401432
# 12  0.851235  0.394639  0.948047   1.144849      -0.053351       0.135273
# 13  0.728269  0.466449  0.995645   1.009572      -0.004365       0.009527
# 14  0.446922  0.654931  0.545356   2.623487      -0.606317       0.964505
# 15  -0.43003  0.667174  0.180527   2.991698      -1.711873       1.095841
# 16 -0.628641  0.529584  0.556336    1.35199      -0.586383       0.301578
# 17  0.479015  0.631928  0.654393   2.010461      -0.424047       0.698364
# 18 -0.560865  0.574889  0.347774   1.797161      -1.056202       0.586208
# 19  0.248986  0.803372  0.581015   2.015787      -0.542979       0.701010
# 20  0.264032  0.791755  0.584197   2.023612      -0.537517       0.704884
# 21  -0.15877   0.87385  0.549115   1.664636      -0.599447       0.509607
#
#      q-value
# 0   0.003674
# 1   0.005832
# 2    0.13828
# 3   0.188561
# 4    0.27022
# 5   0.323956
# 6   0.323956
# 7   0.325017
# 8    0.33939
# 9    0.33939
# 10  0.655303
# 11  0.667851
# 12  0.667851
# 13  0.732991
# 14  0.772517
# 15  0.772517
# 16  0.772517
# 17  0.772517
# 18  0.772517
# 19  0.841628
# 20  0.841628
# 21   0.87385

# %%
MyVisualization.forest_plot(coxph_mv_df, title='CPTAC-iCCA Cohort Multivariate Cox Regression', figure_width=5, figure_height=6, tick_fontsize=8)

# %%
coxph_uni_df = MyRFunctions.coxph_multivariate(surv_df, all_clinical_feats_df[['R4_ssGSEA']])
coxph_uni_df
# Out:
# [1] "AIC of cox model:  931.077415567599"
# [1] "Proportional Hazards Assumption: "
#              chisq df          p
# R4_ssGSEA 4.868048  1 0.02735843
# GLOBAL    4.868048  1 0.02735843
#     Variable      coef exp(coef)  se(coef)         z  Pr(>|z|) lower .95  \
# 0  R4_ssGSEA  0.431023  1.538831  0.118577  3.634952  0.000278  1.219713
#
#   upper .95  log_lower .95  log_upper .95   q-value
# 0  1.941441       0.198616       0.663431  0.000278

# %%
MyLib.save_csv(coxph_mv_df, 'CPTAC_iCCA_cox_mutlivariate_R4_ssGSEA.csv', index=False)
# Out:
# File  Remaining_Analyses/output_figs_patients/CPTAC_iCCA_cox_mutlivariate_R4_ssGSEA.csv saved, shape: (22, 11)

# %% [markdown]
# ## CSGALNACT1

# %%
df = exp_df.T[['CSGALNACT1']].copy()
df['Group'] = (CPTAC_iCCA_mut_df['BAP1_MT'] | CPTAC_iCCA_mut_df['FGFR2_MT']).astype(int)
df['Group'] = df['Group'].replace({0: 'WT', 1: 'BAP1/FGFR2'})
df.head(10)
# Out:
#                  Sample ID
# Gene  CSGALNACT1       Group
# 111                                   4.519          WT
# 113                                   5.215  BAP1/FGFR2
# 115                                   3.504          WT
# 117                                   6.305          WT
# 121                                   3.206          WT
# 123                                   4.915          WT
# 125                                   4.357  BAP1/FGFR2
# 127                                   4.225          WT
# 131                                   4.135          WT
# 133                                   4.118          WT

# %%
color = {'WT':'#c9c7c7', 'BAP1/FGFR2': '#a63603'}
x = 'Group'
gene = 'CSGALNACT1'
title = 'CPTAC-iCCA Cohort'
Utils.compare_visualize_cat_features(df, x=x, y=gene, color_dic=color, y_label=f'{gene} mRNA Expression', test='ranksum', title=title, title_height=1., title_fontsize=7, figure_width=1.2, figure_height=1.4, label_fontsize=6, label_newline=True, ylim_top=10, ytick_step=2.5,save_figure=True)
# Out:
# ranksum p-value=6.506983941510711e-06
# There is a significant association.

# %% [markdown]
# ## TP63

# %%
C6_features = ['FAT2', 'CASP1', 'IRF6', 'KRT15', 'SERPINB13']

# %%
ssgsea_df = MyRFunctions.ssgsea(exp_df, C6_features)
# Out:
# [1] "Calculating ranks..."
# [1] "Calculating absolute values from ranks..."
# [1] "Normalizing..."

# %%
fu_icca_C6_ssgsea_df = zscore(ssgsea_df)
fu_icca_C6_ssgsea_df
# Out:
#        ssGSEA
# 111 -1.457838
# 113  0.361507
# 115 -0.146662
# 117 -1.125057
# 121 -0.772487
# ..        ...
# 981 -0.027887
# 983 -0.765307
# 987 -0.592573
# 993 -0.377101
# 995  0.301998
#
# [249 rows x 1 columns]

# %%
df = pd.concat([fu_icca_C6_ssgsea_df, exp_df.T[['TP63']]], axis=1)
df
# Out:
#        ssGSEA   TP63
# 111 -1.457838  0.690
# 113  0.361507  0.366
# 115 -0.146662  0.886
# 117 -1.125057  0.173
# 121 -0.772487  0.384
# ..        ...    ...
# 981 -0.027887  1.946
# 983 -0.765307  0.395
# 987 -0.592573  1.810
# 993 -0.377101  0.812
# 995  0.301998  2.767
#
# [249 rows x 2 columns]

# %%
# MyLib.save_csv(df, 'CPTAC_iCCA_TP63_5genes.csv')

# %%
x = 'TP63'
y = 'ssGSEA'
points_color = '#6b676e'
line_color = '#C1914B'

MyVisualization.reg_plot(data_df=df, x_col=x, y_col=y, title=f'CPTAC-iCCA Cohort ($n$={df.shape[0]})', points_color_code=points_color, line_color_code=line_color, ylabel='ssGSEA Score',  xlabel=f"{x} mRNA Expression" , marker='o', title_height=1.1, ylim_top=6,  text_height=.95, ytick_step=2, file_name=f'CPTAC_iCCA_{x}_{y}')
# Out:
# p-value:  9.520730929881043e-32

# %% [markdown]
# ### Patient Stratification

# %%
tp63_df = exp_df.T[['TP63']].copy()
MyVisualization.plot_distribution(tp63_df['TP63'], title='CPTAC-iCCA Cohort TP63 mRNA Expression', x_vline=3.5)

# %%
tp63_thr= 3.5
top_tp63_df = tp63_df[tp63_df['TP63']>tp63_thr][['TP63']]
top_tp63_df.shape
# Out:
# (20, 1)

# %%
percentage = (top_tp63_df.shape[0] / tp63_df.shape[0]) * 100
print('Percentage of patients with high expression of TP63:', round(percentage, 2))
# Out:
# Percentage of patients with high expression of TP63: 8.03

# %%
tp63_df['TP63_High'] = (tp63_df['TP63'] > tp63_thr).astype(int)
tp63_df
# Out:
#                  Sample ID
# Gene   TP63  TP63_High
# 111                              0.690          0
# 113                              0.366          0
# 115                              0.886          0
# 117                              0.173          0
# 121                              0.384          0
# ..                                 ...        ...
# 981                              1.946          0
# 983                              0.395          0
# 987                              1.810          0
# 993                              0.812          0
# 995                              2.767          0
#
# [249 rows x 2 columns]

# %% [markdown]
# ### Save TP63 Results

# %%
tp63_all_df = pd.concat([tp63_df['TP63_High'], df['ssGSEA']], axis=1)
tp63_all_df
# Out:
#      TP63_High    ssGSEA
# 111          0 -1.457838
# 113          0  0.361507
# 115          0 -0.146662
# 117          0 -1.125057
# 121          0 -0.772487
# ..         ...       ...
# 981          0 -0.027887
# 983          0 -0.765307
# 987          0 -0.592573
# 993          0 -0.377101
# 995          0  0.301998
#
# [249 rows x 2 columns]

# %%
MyLib.save_csv(tp63_all_df, f'CPTAC-iCCA_TP63_mRNA_status_ssGSEA.csv')
# Out:
# File  Remaining_Analyses/output_figs_patients/CPTAC-iCCA_TP63_mRNA_status_ssGSEA.csv saved, shape: (249, 2)

# %% [markdown]
# ### TP63 Survival Analysis

# %%
surv_df = info_df[['OS, overall survival (day)', 'OS_event']].dropna(axis=0, how='all').astype(float)
surv_df['Group'] = 0  #'Low ssGSEA'
surv_df.loc[tp63_df.loc[surv_df.index, 'TP63_High'] == 1, 'Group'] = 1  #'High ssGSEA'
surv_df
# Out:
#             OS, overall survival (day)  OS_event  Group
# Patient_ID
# 111                              682.0       1.0      0
# 113                              183.0       1.0      0
# 115                             1806.0       0.0      0
# 117                              808.0       1.0      0
# 121                             1317.0       0.0      0
# ...                                ...       ...    ...
# 981                              447.0       0.0      0
# 983                              330.0       0.0      0
# 987                              427.0       0.0      0
# 993                              400.0       0.0      0
# 995                              379.0       0.0      0
#
# [238 rows x 3 columns]

# %%
surv_df[surv_df['Group'] == 1].shape
# Out:
# (17, 3)

# %% [markdown]
# #### Kaplan-Meier

# %%
colors_l = ['#a00000','#077f97']
labels = ['Low', ' High']
MyRFunctions.survival_analysis(surv_df[['OS, overall survival (day)', 'OS_event']], surv_df[['Group']], group='Group', cur_title=f'CPTAC-iCCA Cohort Overal Survival (TP63 mRNA Expression)', legend_lbls=labels, colors_elms=colors_l, plot_path=os.path.join(io_library.output_dir,f'CPTAC-iCCA_Overal_Survival_TP63_Plot_{cluster}.pdf'))
# Out:
# 0 221
# 1 17
# ------

# %% [markdown]
# #### Cox Regression

# %%
all_clinical_feats_df = pd.concat([tp63_df.loc[info_filtered_df.index, ['TP63']], info_filtered_df[cont_feats_cols], cat_clinical_feats_df], axis=1)
all_clinical_feats_df = all_clinical_feats_df.rename(columns={'TP63': 'TP63_mRNA'})
all_clinical_feats_df = all_clinical_feats_df.rename(columns={col: col.replace('-', '_') for col in all_clinical_feats_df.columns})# R cannot take -
all_clinical_feats_df = all_clinical_feats_df.rename(columns={col: col.replace(' ', '_') for col in all_clinical_feats_df.columns})# R cannot take space
all_clinical_feats_df = all_clinical_feats_df.astype(float)
all_clinical_feats_df.shape
# Out:
# (238, 22)

# %%
MyRFunctions.find_collinearity(all_clinical_feats_df.drop(['HBsAg'], axis=1), all_clinical_feats_df[['HBsAg']])
# Out:
# Model :
# HBsAg ~ TP63_mRNA + Age + Tumor_size_diameter + TB_total_bilirubin +
#     CA19_9 + CEA_carcinoembryonic_antigen + Sex_Male + Intrahepatic_metastasis_Yes +
#     Liver_fluke_Yes + Biliary_tract_stone_disease_Yes + Vascular_invasion_Yes +
#     Liver_cirrhosis_Yes + Regional_lymph_Node_metastasis_Yes +
#     Perineural_invasion_Yes + TNM_stage_IB + TNM_stage_II + TNM_stage_IIIA +
#     TNM_stage_IIIB + TNM_stage_IV + Adjuvant_therapies_No_treatment +
#     Adjuvant_therapies_TACE

# %%
coxph_mv_df = MyRFunctions.coxph_multivariate(surv_df[['OS, overall survival (day)', 'OS_event']], all_clinical_feats_df)
coxph_mv_df
# Out:
# [1] "AIC of cox model:  881.746760468878"
# [1] "Proportional Hazards Assumption: "
#                                           chisq df          p
# TP63_mRNA                           0.346079099  1 0.55634109
# HBsAg                               0.117860014  1 0.73136717
# Age                                 2.113187372  1 0.14603487
# Tumor_size_diameter                 3.453393913  1 0.06312203
# TB_total_bilirubin                  0.031149661  1 0.85990691
# CA19_9                              0.030964968  1 0.86031857
# CEA_carcinoembryonic_antigen        0.001522107  1 0.96887908
# Sex_Male                            0.002082808  1 0.96359895
# Intrahepatic_metastasis_Yes         0.934116940  1 0.33379542
# Liver_fluke_Yes                     1.918445201  1 0.16602816
# Biliary_tract_stone_disease_Yes     2.947807194  1 0.08599417
# Vascular_invasion_Yes               0.303956079  1 0.58141288
# Liver_cirrhosis_Yes                 0.758069211  1 0.38393343
# Regional_lymph_Node_metastasis_Yes  3.203071632  1 0.07350011
# Perineural_invasion_Yes             1.016823849  1 0.31327359
# TNM_stage_IB                        0.020433384  1 0.88633331
# TNM_stage_II                        0.134603970  1 0.71370544
# TNM_stage_IIIA                      6.608714662  1 0.01014809
# TNM_stage_IIIB                      2.319541997  1 0.12775764
# TNM_stage_IV                        0.204616315  1 0.65102021
# Adjuvant_therapies_No_treatment     7.094726169  1 0.00773111
# Adjuvant_therapies_TACE             0.205453765  1 0.65035427
# GLOBAL                             35.707173689 22 0.03263298
#                               Variable      coef  exp(coef)  se(coef)  \
# 0                       TNM_stage_IIIA  2.344029  10.423144  0.641167
# 1   Regional_lymph_Node_metastasis_Yes  1.469309   4.346232  0.402482
# 2                            TP63_mRNA  0.135589   1.145212     0.075
# 3                         TNM_stage_IV  1.360434   3.897884  0.635586
# 4                      Liver_fluke_Yes  0.869616   2.385995  0.458031
# 5          Intrahepatic_metastasis_Yes  0.495634   1.641539   0.26843
# 6      Biliary_tract_stone_disease_Yes  1.010482   2.746925  0.529632
# 7                               CA19_9  0.000092   1.000092   0.00005
# 8                   TB_total_bilirubin  0.008212   1.008246  0.004302
# 9                         TNM_stage_II  0.802525   2.231168  0.506269
# 10                                 Age  0.016992   1.017138  0.012241
# 11                 Tumor_size_diameter  0.041748   1.042632  0.047215
# 12                            Sex_Male -0.171805   0.842143  0.225608
# 13                      TNM_stage_IIIB  0.404428   1.498446  0.582164
# 14               Vascular_invasion_Yes   0.15404   1.166538    0.2833
# 15        CEA_carcinoembryonic_antigen  0.001807   1.001808  0.003296
# 16                        TNM_stage_IB  -0.33433   0.715818  0.712856
# 17             Adjuvant_therapies_TACE -0.158451   0.853465  0.422563
# 18             Perineural_invasion_Yes  0.077783   1.080888  0.311529
# 19     Adjuvant_therapies_No_treatment   0.01421   1.014311  0.278049
# 20                 Liver_cirrhosis_Yes  0.041384   1.042252  0.403577
# 21                               HBsAg  0.015963   1.016091  0.316872
#
#            z  Pr(>|z|) lower .95  upper .95  log_lower .95  log_upper .95  \
# 0   3.655877  0.000256  2.966444  36.623617       1.087364       3.600693
# 1   3.650623  0.000262  1.974785   9.565463       0.680460       2.258159
# 2   1.807859  0.070628  0.988657   1.326557      -0.011408       0.282587
# 3   2.140441  0.032319  1.121547  13.546912       0.114709       2.606159
# 4   1.898597  0.057617  0.972283   5.855262      -0.028108       1.767341
# 5    1.84642  0.064831  0.969981   2.778044      -0.030479       1.021747
# 6   1.907895  0.056405  0.972799   7.756582      -0.027578       2.048542
# 7    1.84879  0.064488  0.999994    1.00019      -0.000006       0.000190
# 8   1.908878  0.056278   0.99978   1.016783      -0.000220       0.016644
# 9   1.585176  0.112926  0.827171   6.018237      -0.189744       1.794794
# 10  1.388119  0.165101  0.993024   1.041836      -0.007000       0.040985
# 11  0.884218  0.376578  0.950477   1.143722      -0.050791       0.134288
# 12 -0.761521  0.446346  0.541188    1.31046      -0.613988       0.270378
# 13  0.694698  0.487245  0.478742   4.690079      -0.736593       1.545449
# 14  0.543735  0.586624  0.669505   2.032563      -0.401217       0.709297
# 15  0.548207   0.58355  0.995358   1.008301      -0.004653       0.008266
# 16    -0.469   0.63907  0.177018   2.894589      -1.731502       1.062843
# 17 -0.374977  0.707678   0.37282   1.953762      -0.986659       0.669757
# 18   0.24968  0.802835  0.586958   1.990465      -0.532803       0.688368
# 19  0.051106  0.959241   0.58816   1.749229      -0.530755       0.559175
# 20  0.102544  0.918325   0.47255   2.298785      -0.749612       0.832381
# 21  0.050375  0.959823  0.546023   1.890837      -0.605094       0.637020
#
#      q-value
# 0   0.002878
# 1   0.002878
# 2   0.172647
# 3   0.172647
# 4   0.172647
# 5   0.172647
# 6   0.172647
# 7   0.172647
# 8   0.172647
# 9   0.248438
# 10  0.330201
# 11  0.690394
# 12  0.755354
# 13   0.76567
# 14  0.806608
# 15  0.806608
# 16  0.827031
# 17   0.86494
# 18  0.929598
# 19  0.959823
# 20  0.959823
# 21  0.959823

# %%
MyVisualization.forest_plot(coxph_mv_df, title='CPTAC-iCCA Cohort Multivariate Cox Regression', figure_width=5, figure_height=6, tick_fontsize=8)

# %%
coxph_uni_df = MyRFunctions.coxph_multivariate(surv_df[['OS, overall survival (day)', 'OS_event']], all_clinical_feats_df[['TP63_mRNA']])
coxph_uni_df
# Out:
# [1] "AIC of cox model:  936.682123860388"
# [1] "Proportional Hazards Assumption: "
#               chisq df         p
# TP63_mRNA 0.3570009  1 0.5501766
# GLOBAL    0.3570009  1 0.5501766
#     Variable      coef exp(coef)  se(coef)         z  Pr(>|z|) lower .95  \
# 0  TP63_mRNA  0.191522  1.211092  0.061055  3.136865  0.001708  1.074501
#
#   upper .95  log_lower .95  log_upper .95   q-value
# 0  1.365046       0.071856       0.311188  0.001708

# %%
MyLib.save_csv(coxph_mv_df, 'CPTAC_iCCA_cox_mutlivariate_TP63_ssGSEA.csv', index=False)
# Out:
# File  Remaining_Analyses/output_figs_patients/CPTAC_iCCA_cox_mutlivariate_TP63_ssGSEA.csv saved, shape: (22, 11)

# %% [markdown]
# ## Save results

# %%
CPTAC_iCCA_R3_ssgsea_df
# Out:
#        ssGSEA  High_ssGSEA  R3_ssGSEA
# 111 -1.319180         Rest          0
# 113  0.039561         Rest          0
# 115 -0.630997         Rest          0
# 117  0.603531         Rest          0
# 121  0.848034  R3 Enriched          1
# ..        ...          ...        ...
# 981  0.353042         Rest          0
# 983  0.784060         Rest          0
# 987  0.104952         Rest          0
# 993  0.879380  R3 Enriched          1
# 995  0.054211         Rest          0
#
# [249 rows x 3 columns]

# %%
CPTAC_iCCA_R4_ssgsea_df
# Out:
#        ssGSEA  High_ssGSEA  R4_ssGSEA
# 111 -1.516126         Rest          0
# 113  0.796358  R4 Enriched          1
# 115  0.265844         Rest          0
# 117 -1.586506         Rest          0
# 121  0.370129         Rest          0
# ..        ...          ...        ...
# 981 -0.437273         Rest          0
# 983  0.199961         Rest          0
# 987 -1.213917         Rest          0
# 993  0.206530         Rest          0
# 995 -0.160339         Rest          0
#
# [249 rows x 3 columns]

# %%
d1 = CPTAC_iCCA_R3_ssgsea_df[['ssGSEA', 'High_ssGSEA']]
d1 = d1.rename(columns={'ssGSEA':'R3_ssGSEA', 'High_ssGSEA':f'R3_status (thr={round(R3_threshold,3)})'})
d2 = CPTAC_iCCA_R4_ssgsea_df[['ssGSEA', 'High_ssGSEA']]
d2 = d2.rename(columns={'ssGSEA':'R4_ssGSEA', 'High_ssGSEA':f'R4_status (thr={round(R4_threshold,3)})'})
df = pd.concat([d1, d2, CPTAC_iCCA_mut_df[['mutation_R3', 'mutation_R4']]], axis=1)
MyLib.save_csv(df, 'CPTAC_iCCA_ssGSEA_mutations.csv')
# df = pd.concat([d1, d2, CPTAC_iCCA_mut_df, exp_df.T], axis=1)
# MyLib.save_csv(df, 'CPTAC_iCCA_ssGSEA_mutations_RNA.csv')
# Out:
# File  Remaining_Analyses/output_figs_patients/CPTAC_iCCA_ssGSEA_mutations.csv saved, shape: (249, 6)
